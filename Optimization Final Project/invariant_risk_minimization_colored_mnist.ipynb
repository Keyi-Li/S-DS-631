# %% [markdown]
# # Invariant Risk Minimization
#
# Adapted from https://github.com/reiinakano/invariant-risk-minimization/tree/master
#
# This is an attempt to reproduce the "Colored MNIST" experiments from the
# paper [Invariant Risk Minimization](https://arxiv.org/abs/1907.02893)
# by Arjovsky, et. al.

# %%
import os

import numpy as np
from PIL import Image

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import grad
from torchvision import transforms
from torchvision import datasets
import torchvision.datasets.utils as dataset_utils

# %% [markdown]
# ## Prepare the colored MNIST dataset
#
# We define three environments (two training, one test) by randomly splitting the MNIST dataset in thirds and transforming each example as follows:
# 1. Assign a binary label y to the image based on the digit: y = 0 for digits 0-4
# and y = 1 for digits 5-9.
# 2. Flip the label with 25% probability.
# 3. Color the image either red or green according to its (possibly flipped) label.
# 4. Flip the color with a probability e that depends on the environment: 20% in
# the first training environment, 10% in the second training environment, and
# 90% in the test environment.

# %%
def color_grayscale_arr(arr, red=True):
  """Converts grayscale image to either red or green"""
  assert arr.ndim == 2
  dtype = arr.dtype
  h, w = arr.shape
  arr = np.reshape(arr, [h, w, 1])
  if red:
    arr = np.concatenate([arr,
                          np.zeros((h, w, 2), dtype=dtype)], axis=2)
  else:
    arr = np.concatenate([np.zeros((h, w, 1), dtype=dtype),
                          arr,
                          np.zeros((h, w, 1), dtype=dtype)], axis=2)
  return arr


class ColoredMNIST(datasets.VisionDataset):
  """
  Colored MNIST dataset for testing IRM. Prepared using procedure from https://arxiv.org/pdf/1907.02893.pdf

  Args:
    root (string): Root directory of dataset where ``ColoredMNIST/*.pt`` will exist.
    env (string): Which environment to load. Must be 1 of 'train1', 'train2', 'test', or 'all_train'.
    transform (callable, optional): A function/transform that  takes in an PIL image
      and returns a transformed version. E.g, ``transforms.RandomCrop``
    target_transform (callable, optional): A function/transform that takes in the
      target and transforms it.
  """
  def __init__(self, root='./data', env='train1', transform=None, target_transform=None):
    super(ColoredMNIST, self).__init__(root, transform=transform,
                                target_transform=target_transform)

    self.prepare_colored_mnist()
    if env in ['train1', 'train2', 'test']:
      self.data_label_tuples = torch.load(os.path.join(self.root, 'ColoredMNIST', env) + '.pt')
    elif env == 'all_train':
      self.data_label_tuples = torch.load(os.path.join(self.root, 'ColoredMNIST', 'train1.pt')) + \
                               torch.load(os.path.join(self.root, 'ColoredMNIST', 'train2.pt'))
    else:
      raise RuntimeError(f'{env} env unknown. Valid envs are train1, train2, test, and all_train')

  def __getitem__(self, index):
    """
    Args:
        index (int): Index

    Returns:
        tuple: (image, target) where target is index of the target class.
    """
    img, target = self.data_label_tuples[index]

    if self.transform is not None:
      img = self.transform(img)

    if self.target_transform is not None:
      target = self.target_transform(target)

    return img, target

  def __len__(self):
    return len(self.data_label_tuples)

  def prepare_colored_mnist(self):
    colored_mnist_dir = os.path.join(self.root, 'ColoredMNIST')
    if os.path.exists(os.path.join(colored_mnist_dir, 'train1.pt')) \
        and os.path.exists(os.path.join(colored_mnist_dir, 'train2.pt')) \
        and os.path.exists(os.path.join(colored_mnist_dir, 'test.pt')):
      print('Colored MNIST dataset already exists')
      return

    print('Preparing Colored MNIST')
    train_mnist = datasets.mnist.MNIST(self.root, train=True, download=True)

    train1_set = []
    train2_set = []
    test_set = []
    for idx, (im, label) in enumerate(train_mnist):
      if idx % 10000 == 0:
        print(f'Converting image {idx}/{len(train_mnist)}')
      im_array = np.array(im)

      # Assign a binary label y to the image based on the digit
      binary_label = 0 if label < 5 else 1

      # Flip label with 25% probability
      if np.random.uniform() < 0.25:
        binary_label = binary_label ^ 1

      # Color the image either red or green according to its possibly flipped label
      color_red = binary_label == 0

      # Flip the color with a probability e that depends on the environment
      if idx < 20000:
        # 20% in the first training environment
        if np.random.uniform() < 0.2:
          color_red = not color_red
      elif idx < 40000:
        # 10% in the first training environment
        if np.random.uniform() < 0.1:
          color_red = not color_red
      else:
        # 90% in the test environment
        if np.random.uniform() < 0.9:
          color_red = not color_red

      colored_arr = color_grayscale_arr(im_array, red=color_red)

      if idx < 20000:
        train1_set.append((Image.fromarray(colored_arr), binary_label))
      elif idx < 40000:
        train2_set.append((Image.fromarray(colored_arr), binary_label))
      else:
        test_set.append((Image.fromarray(colored_arr), binary_label))

      # Debug
      # print('original label', type(label), label)
      # print('binary label', binary_label)
      # print('assigned color', 'red' if color_red else 'green')
      # plt.imshow(colored_arr)
      # plt.show()
      # break
    os.makedirs(colored_mnist_dir, exist_ok=True)
    torch.save(train1_set, os.path.join(colored_mnist_dir, 'train1.pt'))
    torch.save(train2_set, os.path.join(colored_mnist_dir, 'train2.pt'))
    torch.save(test_set, os.path.join(colored_mnist_dir, 'test.pt'))

# %% [markdown]
# ### Plot the data

# %%
def plot_dataset_digits(dataset, title):
  fig = plt.figure(figsize=(13, 8))
  columns = 6
  rows = 3
  # ax enables access to manipulate each of subplots
  ax = []

  for i in range(columns * rows):
    img, label = dataset[i]
    # create subplot and append to ax
    ax.append(fig.add_subplot(rows, columns, i + 1))
    ax[-1].set_title("Label: " + str(label))  # set title
    plt.imshow(img)
  plt.suptitle(title, y = 0.92)
  plt.savefig(f"{title}.png")
  plt.show()  # finally, render the plot

# %% [markdown]
# # Plotting the train set

# %%
train1_set = ColoredMNIST(root='./data', env='train1')
plot_dataset_digits(train1_set, "Train Data Overview")
# Out:
# Colored MNIST dataset already exists

# %% [markdown]
# # Plotting the test set

# %%
test_set = ColoredMNIST(root='./data', env='test')
plot_dataset_digits(test_set, "Test Data Overview")
# Out:
# Colored MNIST dataset already exists

# %% [markdown]
# Notice how the correlation between color and label are reversed in the train and test set.

# %% [markdown]
# ## Define neural network
#
# The paper uses an MLP but a Convnet works fine too.

# %%
class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = nn.Linear(3 * 28 * 28, 512)
    self.fc2 = nn.Linear(512, 512)
    self.fc3 = nn.Linear(512, 1)

  def forward(self, x):
    x = x.view(-1, 3 * 28 * 28)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    logits = self.fc3(x).flatten()
    return logits


class ConvNet(nn.Module):
  def __init__(self):
    super(ConvNet, self).__init__()
    self.conv1 = nn.Conv2d(3, 20, 5, 1)
    self.conv2 = nn.Conv2d(20, 50, 5, 1)
    self.fc1 = nn.Linear(4 * 4 * 50, 500)
    self.fc2 = nn.Linear(500, 1)

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = F.max_pool2d(x, 2, 2)
    x = F.relu(self.conv2(x))
    x = F.max_pool2d(x, 2, 2)
    x = x.view(-1, 4 * 4 * 50)
    x = F.relu(self.fc1(x))
    logits = self.fc2(x).flatten()
    return logits

# %% [markdown]
# ## Test ERM as a baseline
#
# Using ERM as a baseline, we expect to train a neural network that uses color instead of the actual digit to classify, completely failing on the test set when the colors are switched.

# %%
def test_model(model, device, test_loader, set_name="test set"):
  model.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      data, target = data.to(device), target.to(device).float()
      output = model(data)
      test_loss += F.binary_cross_entropy_with_logits(output, target, reduction='sum').item()  # sum up batch loss
      pred = torch.where(torch.gt(output, torch.Tensor([0.0]).to(device)),
                         torch.Tensor([1.0]).to(device),
                         torch.Tensor([0.0]).to(device))  # get the index of the max log-probability
      correct += pred.eq(target.view_as(pred)).sum().item()

  test_loss /= len(test_loader.dataset)

  print('\nPerformance on {}: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
    set_name, test_loss, correct, len(test_loader.dataset),
    100. * correct / len(test_loader.dataset)))

  return 100. * correct / len(test_loader.dataset)


def erm_train(model, device, train_loader, optimizer, epoch):
  model.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    data, target = data.to(device), target.to(device).float()
    optimizer.zero_grad()
    output = model(data)
    loss = F.binary_cross_entropy_with_logits(output, target)
    loss.backward()
    optimizer.step()
    if batch_idx % 10 == 0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        epoch, batch_idx * len(data), len(train_loader.dataset),
               100. * batch_idx / len(train_loader), loss.item()))


def train_and_test_erm():
  use_cuda = torch.cuda.is_available()
  device = torch.device("cuda" if use_cuda else "cpu")

  kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
  all_train_loader = torch.utils.data.DataLoader(
    ColoredMNIST(root='./data', env='all_train',
                 transform=transforms.Compose([
                     transforms.ToTensor(),
                     transforms.Normalize((0.1307, 0.1307, 0.), (0.3081, 0.3081, 0.3081))
                   ])),
    batch_size=64, shuffle=True, **kwargs)

  test_loader = torch.utils.data.DataLoader(
    ColoredMNIST(root='./data', env='test', transform=transforms.Compose([
      transforms.ToTensor(),
      transforms.Normalize((0.1307, 0.1307, 0.), (0.3081, 0.3081, 0.3081))
    ])),
    batch_size=1000, shuffle=True, **kwargs)

  model = ConvNet().to(device)
  optimizer = optim.Adam(model.parameters(), lr=0.01)

  for epoch in range(1, 2):
    erm_train(model, device, all_train_loader, optimizer, epoch)
    test_model(model, device, all_train_loader, set_name='train set')
    test_model(model, device, test_loader)

  return model

model_ERM = train_and_test_erm()
# Out:
# Colored MNIST dataset already exists
# Colored MNIST dataset already exists
# Train Epoch: 1 [0/40000 (0%)]	Loss: 0.688518
# Train Epoch: 1 [640/40000 (2%)]	Loss: 0.559275
# Train Epoch: 1 [1280/40000 (3%)]	Loss: 0.431949
# Train Epoch: 1 [1920/40000 (5%)]	Loss: 0.527383
# Train Epoch: 1 [2560/40000 (6%)]	Loss: 0.546894
# Train Epoch: 1 [3200/40000 (8%)]	Loss: 0.472885
# Train Epoch: 1 [3840/40000 (10%)]	Loss: 0.483389
# Train Epoch: 1 [4480/40000 (11%)]	Loss: 0.474079
# Train Epoch: 1 [5120/40000 (13%)]	Loss: 0.369132
# Train Epoch: 1 [5760/40000 (14%)]	Loss: 0.371447
# Train Epoch: 1 [6400/40000 (16%)]	Loss: 0.408254
# Train Epoch: 1 [7040/40000 (18%)]	Loss: 0.420470
# Train Epoch: 1 [7680/40000 (19%)]	Loss: 0.393348
# Train Epoch: 1 [8320/40000 (21%)]	Loss: 0.286127
# Train Epoch: 1 [8960/40000 (22%)]	Loss: 0.459980
# Train Epoch: 1 [9600/40000 (24%)]	Loss: 0.403716
# Train Epoch: 1 [10240/40000 (26%)]	Loss: 0.386007
# Train Epoch: 1 [10880/40000 (27%)]	Loss: 0.402848
# Train Epoch: 1 [11520/40000 (29%)]	Loss: 0.426993
# Train Epoch: 1 [12160/40000 (30%)]	Loss: 0.380997
# Train Epoch: 1 [12800/40000 (32%)]	Loss: 0.518641
# Train Epoch: 1 [13440/40000 (34%)]	Loss: 0.406817
# Train Epoch: 1 [14080/40000 (35%)]	Loss: 0.286193
# Train Epoch: 1 [14720/40000 (37%)]	Loss: 0.436351
# Train Epoch: 1 [15360/40000 (38%)]	Loss: 0.494544
# Train Epoch: 1 [16000/40000 (40%)]	Loss: 0.425840
# Train Epoch: 1 [16640/40000 (42%)]	Loss: 0.343014
# Train Epoch: 1 [17280/40000 (43%)]	Loss: 0.369122
# Train Epoch: 1 [17920/40000 (45%)]	Loss: 0.387755
# Train Epoch: 1 [18560/40000 (46%)]	Loss: 0.544143
# Train Epoch: 1 [19200/40000 (48%)]	Loss: 0.349639
# Train Epoch: 1 [19840/40000 (50%)]	Loss: 0.365769
# Train Epoch: 1 [20480/40000 (51%)]	Loss: 0.498878
# Train Epoch: 1 [21120/40000 (53%)]	Loss: 0.357534
# Train Epoch: 1 [21760/40000 (54%)]	Loss: 0.385888
# Train Epoch: 1 [22400/40000 (56%)]	Loss: 0.342061
# Train Epoch: 1 [23040/40000 (58%)]	Loss: 0.344301
# Train Epoch: 1 [23680/40000 (59%)]	Loss: 0.455525
# Train Epoch: 1 [24320/40000 (61%)]	Loss: 0.337639
# Train Epoch: 1 [24960/40000 (62%)]	Loss: 0.445415
# Train Epoch: 1 [25600/40000 (64%)]	Loss: 0.233753
# Train Epoch: 1 [26240/40000 (66%)]	Loss: 0.430989
# Train Epoch: 1 [26880/40000 (67%)]	Loss: 0.527323
# Train Epoch: 1 [27520/40000 (69%)]	Loss: 0.495663
# Train Epoch: 1 [28160/40000 (70%)]	Loss: 0.438773
# Train Epoch: 1 [28800/40000 (72%)]	Loss: 0.369430
# Train Epoch: 1 [29440/40000 (74%)]	Loss: 0.514339
# Train Epoch: 1 [30080/40000 (75%)]	Loss: 0.456021
# Train Epoch: 1 [30720/40000 (77%)]	Loss: 0.349743
# Train Epoch: 1 [31360/40000 (78%)]	Loss: 0.220575
# Train Epoch: 1 [32000/40000 (80%)]	Loss: 0.205826
# Train Epoch: 1 [32640/40000 (82%)]	Loss: 0.323234
# Train Epoch: 1 [33280/40000 (83%)]	Loss: 0.407110
# Train Epoch: 1 [33920/40000 (85%)]	Loss: 0.364797
# Train Epoch: 1 [34560/40000 (86%)]	Loss: 0.325057
# Train Epoch: 1 [35200/40000 (88%)]	Loss: 0.402650
# Train Epoch: 1 [35840/40000 (90%)]	Loss: 0.531428
# Train Epoch: 1 [36480/40000 (91%)]	Loss: 0.409361
# Train Epoch: 1 [37120/40000 (93%)]	Loss: 0.413447
# Train Epoch: 1 [37760/40000 (94%)]	Loss: 0.449512
# Train Epoch: 1 [38400/40000 (96%)]	Loss: 0.276870
# Train Epoch: 1 [39040/40000 (98%)]	Loss: 0.369169
# Train Epoch: 1 [39680/40000 (99%)]	Loss: 0.348150
#
# Performance on train set: Average loss: 0.3953, Accuracy: 34068/40000 (85.17%)
#
#
# Performance on test set: Average loss: 1.6183, Accuracy: 1974/20000 (9.87%)

# %% [markdown]
# ## IRM
#
# After trying lots of hyperparameters and various tricks, this implementation
# seems to consistently achieve the paper-reported values
# (train accuracy > 70%, test accuracy > 60%), though there might be a bit of
# instability depending on the random seed.
#
# The most common failure case is when the gradient norm penalty term is weighted
# too highly relative to the ERM term. In this case, Φ converges to a function that
# returns the same value for all inputs. The classifier cannot recover from this point
# and the accuracy is stuck at 50% for all environments. This makes sense mathematically.
# If the intermediate representation is the same regardless of input, then *any*
# classifier is the ideal classifier, resulting in the penalty gradient being 0.
#
# Another failure case is when the gradient norm penalty is too low and the
# optimization essentially acts as in ERM (train accuracy > 80%, test accuracy ~10%).
#
# The most important trick I used to get this to work is through scheduled
# increase of the gradient norm penalty weight.
# We start at 0 for the gradient norm penalty weight, essentially beginning as ERM,
# then slowly increase it per epoch.
#
# I use early stopping to stop training once the accuracy on all environments,
# including the test set, reach an acceptable value. Yes, stopping training based on
# performance on the test set is not good practice, but I could not
# find a principled way of stopping training by only observing performance on the
# training environments. One thing that might be needed when applying IRM to
# real-world datasets is to leave out a separate environment as a validation set,
# which we can use for early stopping. The downside is we'll need a minimum of 4
# environments to perform IRM (2 train, 1 validation, 1 test).

# %%
def compute_irm_penalty(losses, dummy):
  g1 = grad(losses[0::2].mean(), dummy, create_graph=True)[0]
  g2 = grad(losses[1::2].mean(), dummy, create_graph=True)[0]
  return (g1 * g2).sum()


def irm_train(model, device, train_loaders, optimizer, epoch):
  model.train()

  train_loaders = [iter(x) for x in train_loaders]

  dummy_w = torch.nn.Parameter(torch.Tensor([1.0])).to(device)

  batch_idx = 0
  penalty_multiplier = epoch ** 1.6
  print(f'Using penalty multiplier {penalty_multiplier}')
  while True:
    optimizer.zero_grad()
    error = 0
    penalty = 0
    for loader in train_loaders:
      data, target = next(loader, (None, None))
      if data is None:
        return
      data, target = data.to(device), target.to(device).float()
      output = model(data)
      loss_erm = F.binary_cross_entropy_with_logits(output * dummy_w, target, reduction='none')
      penalty += compute_irm_penalty(loss_erm, dummy_w)
      error += loss_erm.mean()
    (error + penalty_multiplier * penalty).backward()
    optimizer.step()
    if batch_idx % 2 == 0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tERM loss: {:.6f}\tGrad penalty: {:.6f}'.format(
        epoch, batch_idx * len(data), len(train_loaders[0]),
               100. * batch_idx / len(train_loaders[0]), error.item(), penalty.item()))
      print('First 20 logits', output.data.cpu().numpy()[:20])

    batch_idx += 1


def train_and_test_irm():
  use_cuda = torch.cuda.is_available()
  device = torch.device("cuda" if use_cuda else "cpu")

  kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
  train1_loader = torch.utils.data.DataLoader(
    ColoredMNIST(root='./data', env='train1',
                 transform=transforms.Compose([
                     transforms.ToTensor(),
                     transforms.Normalize((0.1307, 0.1307, 0.), (0.3081, 0.3081, 0.3081))
                   ])),
    batch_size=2000, shuffle=True, **kwargs)

  train2_loader = torch.utils.data.DataLoader(
    ColoredMNIST(root='./data', env='train2',
                 transform=transforms.Compose([
                     transforms.ToTensor(),
                     transforms.Normalize((0.1307, 0.1307, 0.), (0.3081, 0.3081, 0.3081))
                   ])),
    batch_size=2000, shuffle=True, **kwargs)

  test_loader = torch.utils.data.DataLoader(
    ColoredMNIST(root='./data', env='test', transform=transforms.Compose([
      transforms.ToTensor(),
      transforms.Normalize((0.1307, 0.1307, 0.), (0.3081, 0.3081, 0.3081))
    ])),
    batch_size=1000, shuffle=True, **kwargs)

  model = ConvNet().to(device)
  optimizer = optim.Adam(model.parameters(), lr=0.001)

  for epoch in range(1, 100):
    irm_train(model, device, [train1_loader, train2_loader], optimizer, epoch)
    train1_acc = test_model(model, device, train1_loader, set_name='train1 set')
    train2_acc = test_model(model, device, train2_loader, set_name='train2 set')
    test_acc = test_model(model, device, test_loader)
    if train1_acc > 70 and train2_acc > 70 and test_acc > 60:
      print('found acceptable values. stopping training.')
      return model

# %%
model_IRM = train_and_test_irm()
# Out:
# Colored MNIST dataset already exists
# Colored MNIST dataset already exists
# Colored MNIST dataset already exists
# Using penalty multiplier 1.0
# Train Epoch: 1 [0/10 (0%)]	ERM loss: 1.387846	Grad penalty: 0.000006
# First 20 logits [0.08573149 0.07942905 0.03796237 0.08442064 0.08061878 0.07244651
#  0.05792062 0.07123487 0.06405146 0.05849057 0.05790287 0.08706637
#  0.0992713  0.12582594 0.05171401 0.06450412 0.09586515 0.06560228
#  0.1260701  0.10222334]
# Train Epoch: 1 [4000/10 (20%)]	ERM loss: 0.974356	Grad penalty: 0.030039
# First 20 logits [ 0.6584027   0.6271641   0.6944711   0.7567121  -0.7573705  -0.92856747
#  -0.9152378  -1.1355367   0.40773165  0.80882454  0.6107371  -1.0861549
#  -1.2111772  -0.76092553  0.5775498   0.65341854 -1.4063641   0.6683344
#  -1.2060049  -1.3118285 ]
# Train Epoch: 1 [8000/10 (40%)]	ERM loss: 0.930202	Grad penalty: 0.113620
# First 20 logits [ 2.7323027  2.7212114  3.0650635 -3.5688827 -3.0758774 -4.263544
#  -2.1500692 -3.599      2.3290548  2.4404442  1.7187177 -2.2936645
#   2.2332668 -2.6852198  2.3970096 -1.2993622 -2.9296474  2.5738978
#  -2.4879634  2.8218038]
# Train Epoch: 1 [12000/10 (60%)]	ERM loss: 0.877100	Grad penalty: 0.010253
# First 20 logits [-1.7208529  -1.4645654  -2.53683    -1.0001479  -1.8371172  -0.3728849
#  -0.8556954  -1.8126737  -0.91920245 -2.2641976  -2.227017    1.8395438
#  -2.053643    1.4038315   1.6201105   1.7109601   2.0130394   1.8474168
#  -1.178941    1.5700936 ]
# Train Epoch: 1 [16000/10 (80%)]	ERM loss: 0.889451	Grad penalty: 0.028177
# First 20 logits [ 1.0323493   0.7837102   1.1497499   0.9684419   1.1907585  -1.6266246
#  -1.9761004   0.59323025  1.1377544  -0.7239833  -1.051416   -0.73913956
#  -1.5796282   0.93506324 -1.7765262   0.8103134   1.0325264  -1.5301206
#  -1.476943    1.0474324 ]
#
# Performance on train1 set: Average loss: 0.5073, Accuracy: 16021/20000 (80.11%)
#
#
# Performance on train2 set: Average loss: 0.3727, Accuracy: 18047/20000 (90.23%)
#
#
# Performance on test set: Average loss: 1.4342, Accuracy: 1974/20000 (9.87%)
#
# Using penalty multiplier 3.0314331330207964
# Train Epoch: 2 [0/10 (0%)]	ERM loss: 0.881049	Grad penalty: 0.016908
# First 20 logits [ 1.167268   -2.6485274   1.0926195   0.51292336  1.2292182   1.2265381
#   0.8048387  -1.1624745  -1.5346963   0.9010784   1.3164657  -2.511748
#   1.0557536   1.1051865  -1.7794323  -1.4916958  -1.8373609  -2.3707964
#   0.95816404 -1.3353423 ]
# Train Epoch: 2 [4000/10 (20%)]	ERM loss: 0.834795	Grad penalty: 0.017822
# First 20 logits [-1.8699387 -2.1974466 -2.4366746  1.075284  -2.299941  -1.8336103
#  -2.2099395 -3.1319027 -2.6251347  1.4523242  1.236534  -2.595255
#  -2.8253965  1.3395399 -2.7568529 -1.978201   1.1816108  1.5605649
#  -3.2177777 -1.8127608]
# Train Epoch: 2 [8000/10 (40%)]	ERM loss: 0.846993	Grad penalty: 0.014210
# First 20 logits [-1.2915493  -1.5528768  -0.90671295 -1.7003067   1.8829722  -2.4987493
#  -1.6953886  -2.6099675  -1.5750158   1.701316    2.080346    2.0304306
#   2.0163717  -1.9754305   2.0705466   1.9732835  -1.1509197   1.3379551
#  -1.7026681   2.061245  ]
# Train Epoch: 2 [12000/10 (60%)]	ERM loss: 0.887843	Grad penalty: 0.009342
# First 20 logits [ 1.3166627  -0.450063    2.3420732  -0.85408986 -0.29861695  2.242062
#   2.2795143  -1.2574404   2.2755222  -1.0316389   2.2234924   1.7452736
#   2.1047907   1.6458231   1.6495339   2.031692    1.6586024   2.3316195
#  -1.3136777   1.6766099 ]
# Train Epoch: 2 [16000/10 (80%)]	ERM loss: 0.872278	Grad penalty: 0.015599
# First 20 logits [-0.96244746  1.8320402  -1.1101682   1.0559806  -1.3798579   1.9388934
#  -1.2270083   1.3444825   1.7852399  -1.8739945   2.0875785   2.4801972
#  -1.1756352  -1.7150906  -1.4648482  -1.5706398  -1.1335818   2.2243733
#  -1.0974765   2.0087729 ]
#
# Performance on train1 set: Average loss: 0.4979, Accuracy: 16021/20000 (80.11%)
#
#
# Performance on train2 set: Average loss: 0.3254, Accuracy: 18047/20000 (90.23%)
#
#
# Performance on test set: Average loss: 1.6895, Accuracy: 1974/20000 (9.87%)
#
# Using penalty multiplier 5.799546134795289
# Train Epoch: 3 [0/10 (0%)]	ERM loss: 0.845927	Grad penalty: 0.013273
# First 20 logits [ 1.6765637  2.0234776  1.9598645  1.4510725 -2.2065766 -1.5586308
#   1.923735   1.5834885  1.8376242  1.5008351 -1.9833246  1.5742208
#   1.8473179  1.0184224 -1.9364966  0.9776282  2.295603  -1.7389842
#   2.1181443 -2.184768 ]
# Train Epoch: 3 [4000/10 (20%)]	ERM loss: 0.814710	Grad penalty: 0.009702
# First 20 logits [ 1.3572389 -2.048399  -1.3583746 -2.1041288 -1.901963   1.1009856
#   1.1926116  1.7455398 -1.876869  -1.7184281  1.6495335 -1.8577179
#  -2.686946  -1.7865065 -1.8529751 -1.5661907  1.429898  -2.2470644
#  -2.0839093 -2.33809  ]
# Train Epoch: 3 [8000/10 (40%)]	ERM loss: 0.828916	Grad penalty: 0.015586
# First 20 logits [ 1.7088598  1.3133262 -1.582873  -1.8328259 -2.3679097 -2.0495884
#  -2.1261113  1.1861088 -1.6694142 -2.1899817 -1.5720342 -1.7050616
#  -2.1214912  1.6452867 -2.3382013 -2.1900797  1.522974  -2.2574434
#   1.5390581 -2.2394106]
# Train Epoch: 3 [12000/10 (60%)]	ERM loss: 0.795720	Grad penalty: 0.016758
# First 20 logits [ 1.3293077 -1.7572173 -2.2394917 -1.3092188  2.4257808 -2.0166538
#   2.0517814  2.0636759  1.9563311  1.7269214  1.7524887 -1.9496349
#   1.6562141 -1.9193492 -1.533976  -1.377098  -1.4680158  1.7643752
#  -1.7418661  1.6851033]
# Train Epoch: 3 [16000/10 (80%)]	ERM loss: 0.814636	Grad penalty: 0.014180
# First 20 logits [ 1.050533  -1.7365348  2.4389486  2.6230476 -1.9561256 -1.2430472
#  -1.5050561  1.2954164 -1.6818368  2.416227   0.865869   2.3349307
#  -1.5439634  2.75302   -2.0266302 -1.9360069  2.1363287  2.5914876
#   1.7831223  1.9629323]
#
# Performance on train1 set: Average loss: 0.4727, Accuracy: 16007/20000 (80.03%)
#
#
# Performance on train2 set: Average loss: 0.3305, Accuracy: 18020/20000 (90.10%)
#
#
# Performance on test set: Average loss: 1.4695, Accuracy: 2074/20000 (10.37%)
#
# Using penalty multiplier 9.18958683997628
# Train Epoch: 4 [0/10 (0%)]	ERM loss: 0.806844	Grad penalty: 0.011826
# First 20 logits [ 1.9065614   2.4454181   1.035997   -1.369007    0.8275195  -1.6194496
#  -1.6325245   0.87258637 -1.8209636  -1.4500113  -0.78691393  1.8836561
#  -1.004494    1.5415586   1.6851887   1.4581201   1.680306   -1.5859804
#  -1.9363309  -0.89475244]
# Train Epoch: 4 [4000/10 (20%)]	ERM loss: 0.773113	Grad penalty: 0.015935
# First 20 logits [ 2.3092287   1.2329159   1.4161168  -1.5909795   1.960266    1.6139232
#  -2.2474256  -2.6837127  -2.2239518  -3.0371406   0.65480924 -1.8226599
#  -2.9168668   0.8959916   1.8636287  -2.3588183   2.5064461   1.0359776
#   2.6870968  -1.6852192 ]
# Train Epoch: 4 [8000/10 (40%)]	ERM loss: 0.841037	Grad penalty: 0.010549
# First 20 logits [-0.93255794  0.88648486  1.3669306  -0.7611971   0.2428377   0.20902643
#   1.9854013   0.73962736 -1.5838155  -1.7945071   2.61314     1.0424222
#   1.7215537  -2.3785884  -2.4766068   1.0130574  -1.9932519   2.4139304
#  -2.039821   -2.2595952 ]
# Train Epoch: 4 [12000/10 (60%)]	ERM loss: 0.837101	Grad penalty: 0.009176
# First 20 logits [-1.7685754  -0.9116939  -2.4813035  -1.2861451   0.33463314  2.042291
#  -2.3710852   1.0401621   2.080083    1.5940396  -1.3996501  -2.8362265
#   2.3925664   2.2415438  -0.26046464 -2.7722206  -2.8886611  -2.6056705
#  -2.0382807  -2.4530268 ]
# Train Epoch: 4 [16000/10 (80%)]	ERM loss: 0.784098	Grad penalty: 0.011270
# First 20 logits [-2.5123212 -1.179269   1.9726131  1.9392117  2.4352868  2.3666227
#   2.0794568 -1.6422571 -2.811492   1.6431823  2.3446176 -1.5590911
#  -2.3987055 -1.6348517 -2.8375485 -3.1651034 -3.0031316 -2.0155964
#  -3.081828  -2.067354 ]
#
# Performance on train1 set: Average loss: 0.4781, Accuracy: 15879/20000 (79.39%)
#
#
# Performance on train2 set: Average loss: 0.3469, Accuracy: 17722/20000 (88.61%)
#
#
# Performance on test set: Average loss: 1.4154, Accuracy: 3050/20000 (15.25%)
#
# Using penalty multiplier 13.132639022018838
# Train Epoch: 5 [0/10 (0%)]	ERM loss: 0.846940	Grad penalty: 0.005550
# First 20 logits [ 2.6969457   2.165504   -0.25350642  2.5200615   0.4920174   1.6651781
#   2.6362188   2.4572072   2.0246334  -1.7139113   1.7442083  -0.37662768
#  -2.1694598   2.513585   -1.6589949   0.5556671   2.4761443  -2.0952468
#   2.9753804  -0.844727  ]
# Train Epoch: 5 [4000/10 (20%)]	ERM loss: 0.862965	Grad penalty: 0.010681
# First 20 logits [ 1.7583504   2.5682874  -2.0272403   1.517188   -1.4063454   1.4388227
#  -0.70515704  0.12841275  1.7185943  -0.28475305 -1.4922807   1.3220074
#  -1.1896927  -0.09772962 -1.0852131   0.67601836 -0.7810124   1.9555284
#   1.2873948  -0.19447778]
# Train Epoch: 5 [8000/10 (40%)]	ERM loss: 0.850694	Grad penalty: 0.006919
# First 20 logits [ 2.8805187  -0.7340852   2.44674     2.2552087   3.1628969   2.1775863
#  -0.38574597  3.1997159   1.6148881  -0.52828014  3.0371394  -2.499247
#   2.3310273   1.3216317   2.8019612  -0.48278257 -0.9222613  -1.8099102
#   0.23350745  0.09147681]
# Train Epoch: 5 [12000/10 (60%)]	ERM loss: 0.827556	Grad penalty: 0.013463
# First 20 logits [ 3.3999584  1.274656   2.3033793 -2.806215  -1.2947077  2.8861067
#  -1.2023727 -1.8553667  2.7487352  2.5399497  2.047944   2.1594563
#  -2.7311018  1.130087   0.1810869 -1.214083  -2.1039903  3.2154772
#   2.4551642  3.2761183]
# Train Epoch: 5 [16000/10 (80%)]	ERM loss: 0.782257	Grad penalty: 0.006941
# First 20 logits [-1.147215    1.9943511  -2.0032158   1.7961466   1.7239183  -0.31365067
#   1.919697   -2.6734345   2.225688    2.3145247   1.4864209  -3.1413093
#  -2.0372548   1.5450095   1.5512033  -3.410643   -3.3502219   2.8046727
#  -0.1661896  -1.9761387 ]
#
# Performance on train1 set: Average loss: 0.4688, Accuracy: 15855/20000 (79.28%)
#
#
# Performance on train2 set: Average loss: 0.3485, Accuracy: 17415/20000 (87.08%)
#
#
# Performance on test set: Average loss: 1.3392, Accuracy: 4675/20000 (23.38%)
#
# Using penalty multiplier 17.580936309501134
# Train Epoch: 6 [0/10 (0%)]	ERM loss: 0.830657	Grad penalty: 0.006086
# First 20 logits [ 1.1505525   0.43195704  0.90337384 -1.9650995   1.9492534  -0.05098296
#  -1.8105186  -2.8153694  -1.9460903  -2.7167192  -3.257612   -0.10300883
#   1.3871578  -1.6140367  -0.43804473 -0.8890377  -0.36625847  2.2979372
#  -1.0947427   2.3435876 ]
# Train Epoch: 6 [4000/10 (20%)]	ERM loss: 0.804561	Grad penalty: 0.007705
# First 20 logits [ 1.1069471  -1.1830146  -0.12392002 -0.7783213   1.6046625   1.7971518
#  -2.0213726  -3.2321362  -3.6630208   1.59207    -3.1717725   1.8311068
#  -2.9328458   0.91073424  2.171291    1.2585733  -3.5351138  -1.7814999
#   0.30681077 -2.205529  ]
# Train Epoch: 6 [8000/10 (40%)]	ERM loss: 0.838299	Grad penalty: 0.009453
# First 20 logits [ 1.0742522   2.9710248  -0.32373226  2.405363    1.5926917   3.1349936
#   1.543505   -0.23723981 -3.0392418   1.4864889   2.013994   -3.2705338
#  -2.223579   -1.4984102  -1.5922153   0.31895444 -3.8029964   2.1181042
#   2.4503448   1.8097142 ]
# Train Epoch: 6 [12000/10 (60%)]	ERM loss: 0.888466	Grad penalty: 0.003744
# First 20 logits [ 2.020781    3.0199668   1.4672226   2.0608482   0.6595461  -2.7231228
#   0.3781374   1.5682573   2.1682918   2.2732809   0.04832797  1.3188288
#   0.9769013  -1.0081339  -2.7554255   0.03976828  2.6688745   0.82196903
#  -1.5469275   2.7211359 ]
# Train Epoch: 6 [16000/10 (80%)]	ERM loss: 0.928610	Grad penalty: 0.003865
# First 20 logits [ 2.65117    -1.34012    -1.7844708  -1.4676744   2.796553    0.15855378
#   1.0931284   0.7534832   1.7127728   1.4438505   1.0767663  -0.33339456
#   0.28707573  1.5216115   1.951199   -1.6639138  -0.90333146 -0.96121746
#   0.53414446  1.587041  ]
#
# Performance on train1 set: Average loss: 0.4737, Accuracy: 15487/20000 (77.44%)
#
#
# Performance on train2 set: Average loss: 0.3863, Accuracy: 16496/20000 (82.48%)
#
#
# Performance on test set: Average loss: 1.1431, Accuracy: 7466/20000 (37.33%)
#
# Using penalty multiplier 22.498670948012276
# Train Epoch: 7 [0/10 (0%)]	ERM loss: 0.867753	Grad penalty: 0.004867
# First 20 logits [ 0.14054126 -2.6593716   1.6406559   2.2361486  -2.25768     2.370037
#   0.73258203  2.4414027   1.4824532   0.15519868 -0.91069686 -1.7389816
#  -1.374206   -0.11139332  2.489485   -2.4206803   1.8595855  -0.03161406
#  -0.1011758   3.0270116 ]
# Train Epoch: 7 [4000/10 (20%)]	ERM loss: 0.819194	Grad penalty: 0.009117
# First 20 logits [-1.9539431   2.7886567   0.12156131 -2.3064053  -2.749062   -0.41647065
#  -1.3506582  -2.1622891  -2.915344    3.7291613  -1.8934952  -0.37788737
#  -0.5846626   2.9527059  -0.42662844 -2.1669338  -0.48766792  2.4483442
#  -0.05071788  2.5260663 ]
# Train Epoch: 7 [8000/10 (40%)]	ERM loss: 0.846119	Grad penalty: 0.003808
# First 20 logits [ 1.6701236   2.9050934   1.0816175  -1.1156094  -2.9861248  -3.3655808
#  -0.13042057 -1.3014598   1.1889856  -2.0904014   1.3243959   0.5998089
#   0.31481346 -2.0334318  -2.6394525   2.393552    0.53779626  0.38778144
#  -3.7824895  -1.6450212 ]
# Train Epoch: 7 [12000/10 (60%)]	ERM loss: 0.938597	Grad penalty: 0.002544
# First 20 logits [-2.2578437   2.126734    1.1757747  -0.00937178 -2.8474686   0.8893524
#  -0.22745015 -1.989776   -2.7115116   1.3345162  -1.2476455   2.1181123
#   0.44427365  1.5064577  -1.1978365   0.91234857 -2.314592    0.25042015
#  -0.5207886  -0.30317235]
# Train Epoch: 7 [16000/10 (80%)]	ERM loss: 0.951012	Grad penalty: -0.000115
# First 20 logits [-2.0170956  -0.18291043  1.4959456  -0.09035102 -0.76160026 -0.3095988
#  -3.982387   -3.2464805  -2.315053    0.22616541  0.15824397  1.8252598
#  -0.6422074   1.672298    2.5947995  -3.1674051  -3.4807065   0.9669131
#   0.8604145  -0.25221932]
#
# Performance on train1 set: Average loss: 0.4842, Accuracy: 15345/20000 (76.72%)
#
#
# Performance on train2 set: Average loss: 0.4083, Accuracy: 16041/20000 (80.20%)
#
#
# Performance on test set: Average loss: 1.0997, Accuracy: 9061/20000 (45.30%)
#
# Using penalty multiplier 27.85761802547598
# Train Epoch: 8 [0/10 (0%)]	ERM loss: 0.887146	Grad penalty: 0.001560
# First 20 logits [ 2.336948   -1.93049     2.569363   -3.1890361   1.1486208   2.4234395
#  -3.5581417  -1.8000884  -2.23981     0.54364926 -3.4665673  -3.0879288
#   2.896186   -0.68469566 -2.0062187  -0.65383536  2.2411656   2.3559988
#  -0.2227587   3.093236  ]
# Train Epoch: 8 [4000/10 (20%)]	ERM loss: 0.818340	Grad penalty: 0.004526
# First 20 logits [ 3.144179    2.54384     2.4954205  -4.5990834   1.7784923   1.2841952
#  -1.4376152   0.28387493 -2.108844   -0.14411332 -0.4254118   2.3853424
#   2.8544145   1.8965653   2.489827   -0.1428125   1.8994285   0.5382724
#  -3.2180371   1.6459723 ]
# Train Epoch: 8 [8000/10 (40%)]	ERM loss: 0.779437	Grad penalty: 0.008531
# First 20 logits [-1.8358225   0.10684926 -2.7797484  -2.5593352   2.061716   -2.6464436
#   2.507307   -0.94370246  0.30927244 -0.4820768  -0.6245589  -0.84275055
#   2.4715133   0.39773956 -2.1117744  -1.4027357   0.9140682  -2.9275928
#   2.2795491   2.3467696 ]
# Train Epoch: 8 [12000/10 (60%)]	ERM loss: 0.794954	Grad penalty: 0.005419
# First 20 logits [-0.0847832   2.4527147  -2.7463224   1.7988747   2.813143   -2.8023143
#   1.8371283   2.5342994   2.2903993   1.5418562  -0.81110996 -2.0919447
#   0.24748719 -1.8477879   0.1598509  -3.2896163   2.0543296  -2.4378421
#   2.0362256   2.5508063 ]
# Train Epoch: 8 [16000/10 (80%)]	ERM loss: 0.837022	Grad penalty: 0.012605
# First 20 logits [-0.19244933  2.7776115   2.2328212   0.17789388  1.0773445  -2.672446
#  -3.065569   -2.0647316   0.41556153  3.4857376  -0.36602166 -1.276882
#   0.47720936 -0.77188325  3.005215   -0.89709795 -1.9856348  -3.0482645
#   2.9601643  -1.5712436 ]
#
# Performance on train1 set: Average loss: 0.4569, Accuracy: 15772/20000 (78.86%)
#
#
# Performance on train2 set: Average loss: 0.3642, Accuracy: 17007/20000 (85.03%)
#
#
# Performance on test set: Average loss: 1.1763, Accuracy: 5892/20000 (29.46%)
#
# Using penalty multiplier 33.63473536961897
# Train Epoch: 9 [0/10 (0%)]	ERM loss: 0.825120	Grad penalty: 0.008124
# First 20 logits [ 2.0096064   2.378227    2.0404854   2.1845708   1.4767845   2.7128646
#  -3.0117404   2.079484    1.1011012   0.9074864   2.4670641   1.3166443
#  -2.6794248  -1.6884959   0.21965185  2.4112756   0.50667864  0.21294829
#   0.48036477  0.7668069 ]
# Train Epoch: 9 [4000/10 (20%)]	ERM loss: 0.834194	Grad penalty: 0.001745
# First 20 logits [ 1.3071293  -2.7252364  -0.08002932 -2.4723186   1.392066    2.1516714
#  -3.877634   -2.6540694   1.9564457  -1.2314743  -0.44574866  0.5235753
#   0.4147649   1.4048824   0.64066255 -0.5317735  -0.7311781   1.384056
#  -2.3790393  -2.0446622 ]
# Train Epoch: 9 [8000/10 (40%)]	ERM loss: 0.880340	Grad penalty: 0.001622
# First 20 logits [ 2.2476735  -3.5580182   1.4861311   0.06501719  0.84669715  2.251187
#  -5.1329803   1.9693451  -0.4743148  -3.02337    -3.1241188  -0.72077584
#   1.9030718   0.07496497  2.4276767  -1.5356052   2.0632308   1.7414699
#   0.08498093 -0.567254  ]
# Train Epoch: 9 [12000/10 (60%)]	ERM loss: 0.853146	Grad penalty: 0.002643
# First 20 logits [-3.878345   -1.4608599  -1.6933669  -0.3124081  -3.356539    1.1494639
#   2.1097806   0.9207175   2.0743887   1.5791649  -0.54527587 -3.1104107
#  -0.26234    -2.764045    1.6880648   1.2609209  -0.61733127  1.4058322
#  -3.6700616   1.864348  ]
# Train Epoch: 9 [16000/10 (80%)]	ERM loss: 0.882291	Grad penalty: 0.001396
# First 20 logits [ 0.8123096   0.9284739  -2.3356526  -3.2617912   2.35087     0.07897348
#   1.6014204   0.37225437 -4.477965    1.0503869   1.8536682   2.2233462
#  -1.2829288   0.7228293  -0.718202    0.0853638  -0.8229932  -2.3445222
#   1.2459311  -3.408522  ]
#
# Performance on train1 set: Average loss: 0.4733, Accuracy: 15520/20000 (77.60%)
#
#
# Performance on train2 set: Average loss: 0.3978, Accuracy: 16237/20000 (81.19%)
#
#
# Performance on test set: Average loss: 1.1043, Accuracy: 8488/20000 (42.44%)
#
# Using penalty multiplier 39.810717055349734
# Train Epoch: 10 [0/10 (0%)]	ERM loss: 0.846000	Grad penalty: 0.003261
# First 20 logits [-2.2071733   1.3060292   1.7165991  -2.191503   -0.5827255  -3.0857668
#  -0.13320917 -3.8441844  -3.7467592  -2.139844    0.4056366  -0.45858768
#   1.3654279   0.31350374 -2.2650032  -2.370595   -2.2342534  -3.719706
#   0.9318692   1.7389647 ]
# Train Epoch: 10 [4000/10 (20%)]	ERM loss: 0.873146	Grad penalty: 0.001954
# First 20 logits [ 1.0748289  -3.9564252   0.8440568   2.4929972  -4.9693813   0.45087513
#  -0.09001753  0.6137207  -0.49870464 -0.00897722 -1.909619    2.1525388
#   1.4070075  -4.6029334  -3.2425838  -4.960429   -0.87670887 -1.0648719
#  -3.706554    0.80440134]
# Train Epoch: 10 [8000/10 (40%)]	ERM loss: 0.917636	Grad penalty: 0.002148
# First 20 logits [ 1.7366022  -1.8975993   2.3381684   0.23115098  0.87585634 -1.2944542
#  -2.4705992  -4.2227817   1.3097739  -0.30647716  0.6040834  -0.45927864
#  -3.7223277  -1.9140731   0.95858264  2.3532856   2.1476746  -2.085621
#  -4.0256047   0.34702602]
# Train Epoch: 10 [12000/10 (60%)]	ERM loss: 0.888343	Grad penalty: 0.001197
# First 20 logits [ 1.8170564  -2.9958527  -0.07195178 -0.572406    1.5178542   0.46014503
#  -2.1305053  -1.106461    0.4982378  -1.3676918   1.1968346  -0.22012818
#   2.1286569   1.3948555   1.5197792  -2.9584143  -0.19248822 -2.0198476
#  -2.8634207  -2.8471482 ]
# Train Epoch: 10 [16000/10 (80%)]	ERM loss: 0.849994	Grad penalty: 0.001983
# First 20 logits [-2.4668496  -0.28746673 -4.0445166   0.13532989  2.9968953   0.16604224
#   0.13790384  2.0649877  -2.4276433  -3.6678143  -3.3552768   1.2642324
#   2.5433505   1.7915581   0.8514779   0.3199943   1.7305769  -2.9266305
#  -2.6093829   2.9736824 ]
#
# Performance on train1 set: Average loss: 0.4637, Accuracy: 15573/20000 (77.86%)
#
#
# Performance on train2 set: Average loss: 0.3854, Accuracy: 16369/20000 (81.84%)
#
#
# Performance on test set: Average loss: 1.1406, Accuracy: 8122/20000 (40.61%)
#
# Using penalty multiplier 46.369060464010914
# Train Epoch: 11 [0/10 (0%)]	ERM loss: 0.801489	Grad penalty: 0.003500
# First 20 logits [-1.9678378  -0.56663954 -3.2564526   2.3775642  -1.5849602  -3.2625983
#   2.1585238   2.2869954   1.0371945   1.8665173   0.00636821 -2.4882603
#  -3.2596245  -2.6001272  -2.9538865   1.308861    1.9520589  -4.0735006
#  -3.8753495  -3.7294497 ]
# Train Epoch: 11 [4000/10 (20%)]	ERM loss: 0.898501	Grad penalty: 0.000608
# First 20 logits [ 1.8153415   0.33915484  1.5875503   2.387119    2.5527692   0.93056864
#  -0.98700804  1.840253    2.6806817  -0.23494273 -2.4803505   2.831592
#   2.5957103  -0.8756744   2.417811   -2.7375827  -0.59331137 -2.7356973
#   0.19714022 -3.2712293 ]
# Train Epoch: 11 [8000/10 (40%)]	ERM loss: 0.861328	Grad penalty: 0.002028
# First 20 logits [-0.65152645 -3.0775428   1.2674469   1.2994653  -3.1595314  -4.1796923
#  -0.19185188 -0.48885465 -3.68303    -0.7460203  -3.6954858  -1.6147443
#   1.0004345  -2.1994483  -2.4232025   2.3794703  -1.0559877  -2.6774263
#  -1.6297684  -1.0977806 ]
# Train Epoch: 11 [12000/10 (60%)]	ERM loss: 0.863050	Grad penalty: 0.001711
# First 20 logits [-0.32421568 -1.1501583   1.8912729  -0.06133702  2.027353    3.0112169
#  -3.9212952   1.8853655   2.0337093  -1.1629863  -5.2845774   0.09812506
#  -0.43813583 -3.838345   -3.813009   -2.6041021  -1.4450141  -2.4372776
#   2.0022478   2.6433835 ]
# Train Epoch: 11 [16000/10 (80%)]	ERM loss: 0.952125	Grad penalty: 0.001789
# First 20 logits [ 1.5645123   2.1547172   0.15582833 -3.729421   -3.044163   -2.968982
#   0.59842074 -2.4234574   0.30739334  0.52491677  0.15720358 -2.805024
#   2.9946702   1.7507107   0.74149275 -1.2853491  -1.9299941   0.14615375
#   2.169085   -2.8917644 ]
#
# Performance on train1 set: Average loss: 0.4783, Accuracy: 15279/20000 (76.39%)
#
#
# Performance on train2 set: Average loss: 0.4266, Accuracy: 15754/20000 (78.77%)
#
#
# Performance on test set: Average loss: 0.9833, Accuracy: 10007/20000 (50.03%)
#
# Using penalty multiplier 53.29543283815009
# Train Epoch: 12 [0/10 (0%)]	ERM loss: 0.912929	Grad penalty: 0.001749
# First 20 logits [ 1.7751399   1.9055547  -1.6994445   0.621431   -0.19260845 -2.5481517
#  -1.7494725  -1.4797941   2.3779724   1.3919741   2.586676    1.808078
#   0.34820122 -0.7656425   0.10418039 -0.6681721   0.19439471 -2.7064426
#   1.8259398   1.6627374 ]
# Train Epoch: 12 [4000/10 (20%)]	ERM loss: 0.946312	Grad penalty: 0.000465
# First 20 logits [-3.775383    2.5139894   2.6824381  -4.196425    2.5102255   0.53238386
#  -2.123642   -1.4440264   1.6214284  -2.9874663  -2.7243567  -2.9875007
#   1.3189721   2.169244    1.8162546   1.2991042   2.5009637  -2.3160532
#   0.5113697  -0.18307373]
# Train Epoch: 12 [8000/10 (40%)]	ERM loss: 0.839594	Grad penalty: 0.002229
# First 20 logits [ 1.002124    1.8050308  -0.14310518 -2.904949    0.05533367 -0.49010238
#  -3.1155093  -2.36396     1.7610953  -2.43952     1.1330489   2.1784506
#   0.3716934   2.4770195  -0.26632252  0.17030531  0.7846161   2.232483
#  -0.9208585  -0.45150176]
# Train Epoch: 12 [12000/10 (60%)]	ERM loss: 0.819402	Grad penalty: -0.000840
# First 20 logits [-0.48977298  1.8249503   1.0149044  -0.06404316 -4.6895275  -0.3402322
#  -0.25554758 -0.45129585 -4.060135    0.16737196 -3.892254    1.2536077
#  -2.359183    1.8230997  -2.1596732  -1.4228859  -1.6441646   2.3633368
#   0.2475519  -4.6803827 ]
# Train Epoch: 12 [16000/10 (80%)]	ERM loss: 0.844890	Grad penalty: 0.002487
# First 20 logits [-6.8734539e-01  7.4733114e-01 -9.5628262e-01  1.8991190e+00
#  -2.2789724e-03  1.9495777e+00 -2.8023460e+00 -2.4360166e+00
#  -3.1817021e+00  1.8436779e+00 -3.5386672e+00 -2.5615125e+00
#  -2.9056106e+00  2.6150270e+00 -3.8612554e+00 -7.3710084e-01
#  -3.3581021e+00 -6.9964302e-01  7.7433717e-01 -3.3263092e+00]
#
# Performance on train1 set: Average loss: 0.4779, Accuracy: 15254/20000 (76.27%)
#
#
# Performance on train2 set: Average loss: 0.4302, Accuracy: 15701/20000 (78.50%)
#
#
# Performance on test set: Average loss: 0.9574, Accuracy: 10220/20000 (51.10%)
#
# Using penalty multiplier 60.57722346046887
# Train Epoch: 13 [0/10 (0%)]	ERM loss: 0.888358	Grad penalty: 0.001711
# First 20 logits [-1.5895126  -3.3715625   0.29823837  1.9315697  -2.3769162   2.606824
#  -1.4344021   0.55846727 -0.4235154   2.1814075  -1.2034099  -1.8540752
#   1.3188938   2.3988266   1.7125732   1.2999474  -2.7307088  -0.71397316
#  -1.2613848   0.86153686]
# Train Epoch: 13 [4000/10 (20%)]	ERM loss: 0.905497	Grad penalty: 0.001042
# First 20 logits [ 0.8356527  -2.644836    2.1471424   1.6613842  -2.3175154   0.37420514
#   0.52284753  1.0603731   0.5556475  -1.3550515   2.1372325  -3.1890776
#   0.24576363  2.8278127   2.657677   -2.7799342   1.437556    0.04771927
#  -2.1894066   1.6689376 ]
# Train Epoch: 13 [8000/10 (40%)]	ERM loss: 0.845285	Grad penalty: 0.001542
# First 20 logits [ 0.4304006  -2.923009    1.9312781  -0.5911594   1.929638    0.7226694
#   0.32364744 -3.7265775  -3.257527    0.5143115  -1.2500852   1.269476
#  -2.5428865  -0.8021513   0.83631796 -2.5896204  -0.83301204  1.5964044
#   0.20974341 -0.80287415]
# Train Epoch: 13 [12000/10 (60%)]	ERM loss: 0.886410	Grad penalty: 0.000838
# First 20 logits [ 2.4966414  -0.79747236  0.13219589 -3.1983066  -1.6230212  -2.1777973
#  -1.8875886   1.7936342   2.1421149   2.4352121   2.1634521  -0.23655191
#  -1.8573893   2.4037552  -0.49028417  0.23955807 -0.28732854 -3.061966
#  -0.30522963 -0.26257554]
# Train Epoch: 13 [16000/10 (80%)]	ERM loss: 0.928953	Grad penalty: 0.001311
# First 20 logits [-2.772614   -1.9515157  -1.2854143  -3.1087346  -1.0046699   0.41742268
#   1.4073526  -0.11488011  1.1457049   0.76270646  0.9727802   0.8950767
#  -0.4478396  -0.33095217  1.0081633   0.44479188  2.9473934  -1.6895604
#  -2.696486    1.7354511 ]
#
# Performance on train1 set: Average loss: 0.5264, Accuracy: 14688/20000 (73.44%)
#
#
# Performance on train2 set: Average loss: 0.4824, Accuracy: 15416/20000 (77.08%)
#
#
# Performance on test set: Average loss: 0.9398, Accuracy: 9025/20000 (45.12%)
#
# Using penalty multiplier 68.20321656073682
# Train Epoch: 14 [0/10 (0%)]	ERM loss: 1.017739	Grad penalty: 0.000045
# First 20 logits [-5.9663975e-01 -1.3590211e+00  2.3641605e+00  2.6828985e+00
#  -1.0300167e-03 -1.3144001e+00  8.5734606e-01  1.7595142e+00
#  -1.0863842e-01  5.8417040e-01  2.3687277e+00  2.6767688e+00
#   3.5079372e-01  2.5311575e+00 -3.1621110e-02 -1.7209631e+00
#  -1.2125505e+00  2.4254854e+00  9.0119773e-01  1.7811067e+00]
# Train Epoch: 14 [4000/10 (20%)]	ERM loss: 1.025602	Grad penalty: 0.000309
# First 20 logits [-1.4932393   1.4953264  -0.02262684  2.6770568  -0.95084953  2.4724758
#  -0.53735787  1.5697554   2.0568314  -1.3991741   0.5262493   2.0707777
#   1.0585804   0.42426294  0.5927785   0.573929    1.7046613  -1.4014585
#   2.2339675  -1.1974536 ]
# Train Epoch: 14 [8000/10 (40%)]	ERM loss: 0.992019	Grad penalty: 0.003057
# First 20 logits [ 2.0668035   0.41938573  1.9762317  -0.654052   -0.49722683  0.71880233
#   0.5937028   2.6258569   1.7281467   0.8149547   0.9173238  -0.56815827
#  -0.57507634 -0.38579518  1.9050779   0.5658976   0.47535726  2.143104
#   0.16035911  1.3938493 ]
# Train Epoch: 14 [12000/10 (60%)]	ERM loss: 0.989743	Grad penalty: 0.001356
# First 20 logits [ 0.94684637 -0.2267851   0.3214341   2.215474    2.3287628  -1.7492752
#  -1.9083937   1.6230406   0.33387777  0.45659932  1.1588281  -0.06321127
#   2.017337    2.5867355   1.7680266   1.9617877   1.021684    1.5522687
#  -1.1341293   1.5917046 ]
# Train Epoch: 14 [16000/10 (80%)]	ERM loss: 0.961917	Grad penalty: 0.002994
# First 20 logits [-1.0296891   2.2827687   2.0040238  -0.06172935  0.524432   -1.0518808
#   0.6954976   0.52802116 -1.2634249   0.60551864  1.3946354   1.0529768
#  -0.3375448   0.9276153   1.490993    0.8288135   2.5348783   0.18019575
#   1.3207965   0.7679083 ]
#
# Performance on train1 set: Average loss: 0.4941, Accuracy: 15074/20000 (75.37%)
#
#
# Performance on train2 set: Average loss: 0.4487, Accuracy: 15635/20000 (78.17%)
#
#
# Performance on test set: Average loss: 0.9289, Accuracy: 9677/20000 (48.38%)
#
# Using penalty multiplier 76.16334587981113
# Train Epoch: 15 [0/10 (0%)]	ERM loss: 0.946250	Grad penalty: 0.001806
# First 20 logits [-1.2915145  -1.7264215   0.01055499 -0.64302653  2.1032002   1.3751712
#   2.5384853   2.011049    1.3417768   2.2238703   2.17488     0.3153515
#  -0.03239439  1.0940154   0.83138937  0.4800881  -2.296006   -2.1300406
#   1.94913     2.1436338 ]
# Train Epoch: 15 [4000/10 (20%)]	ERM loss: 0.937656	Grad penalty: 0.001576
# First 20 logits [ 0.45075342 -2.2514262  -2.0744655  -1.8178393  -2.9404764  -2.599746
#  -1.9056592   3.408872    2.4502428  -1.5948837   2.756592    0.64532393
#   2.4464688  -1.9971787   1.9238452  -3.3575897  -3.259048    0.28885972
#   1.2405964  -2.40204   ]
# Train Epoch: 15 [8000/10 (40%)]	ERM loss: 0.891680	Grad penalty: 0.001316
# First 20 logits [ 1.1938788   2.4493988   2.6109228  -0.17717338  0.41729808  2.0565479
#   0.34269047 -2.4815311   2.5169988   1.9028167  -0.69714236 -1.048111
#  -0.5219325   0.18161306 -3.3789191  -1.1313049   0.48855484  1.2513747
#   0.9689997  -3.3780122 ]
# Train Epoch: 15 [12000/10 (60%)]	ERM loss: 0.887963	Grad penalty: 0.000783
# First 20 logits [ 0.5327195   2.4941094  -2.1301181  -2.3206685  -2.8115592  -1.1468626
#   1.7563751   0.28286862 -2.3973498   0.3449377   0.15508613  2.0365732
#  -3.0382414  -0.68992543  0.3738643  -0.22698477 -2.2287853  -2.7856166
#  -3.8551571  -2.7025688 ]
# Train Epoch: 15 [16000/10 (80%)]	ERM loss: 0.926159	Grad penalty: 0.001510
# First 20 logits [ 1.1753848  -0.79062164 -3.977397    0.03980021 -0.74851    -0.93817484
#   1.3612244  -2.6481338   1.2688593   0.9344282   0.36580426 -0.32035044
#  -1.1579009  -2.4227767  -0.9594627  -0.14268541  0.30098405 -1.5915737
#  -3.2953386   1.1312182 ]
#
# Performance on train1 set: Average loss: 0.4853, Accuracy: 15351/20000 (76.75%)
#
#
# Performance on train2 set: Average loss: 0.4328, Accuracy: 15783/20000 (78.92%)
#
#
# Performance on test set: Average loss: 0.9726, Accuracy: 9987/20000 (49.94%)
#
# Using penalty multiplier 84.44850628946526
# Train Epoch: 16 [0/10 (0%)]	ERM loss: 0.896333	Grad penalty: 0.003066
# First 20 logits [-1.6467062   1.721197   -2.4486647   1.1777214  -1.3891134  -2.3423438
#  -0.40485448  0.17284936  1.0859376   1.2032014  -2.8114762  -0.7610269
#  -3.2900505  -1.0975859  -0.99188066 -2.6782055   0.46072572  0.01316234
#   1.7019035  -3.8385983 ]
# Train Epoch: 16 [4000/10 (20%)]	ERM loss: 0.971382	Grad penalty: 0.000626
# First 20 logits [-2.7108357   1.6127716   1.3447143  -0.92760533 -2.1095314   0.5980863
#  -2.7511423  -3.700631   -3.3705957   0.60652435 -0.3376842  -3.655403
#  -3.3181772  -0.26358172  1.2548481  -3.5102868  -4.9078507  -0.8811808
#  -0.2628329   0.43479124]
# Train Epoch: 16 [8000/10 (40%)]	ERM loss: 0.904224	Grad penalty: 0.001263
# First 20 logits [-0.83635217  0.08172818 -1.8524457  -2.6145434   1.7251874  -3.0072484
#  -3.537696    0.5183938  -2.132298    0.8233086   2.354155   -3.5793457
#  -2.6791732   1.2165986   0.5512845  -1.4615694   1.025865    1.7373868
#  -0.9822349   2.6993663 ]
# Train Epoch: 16 [12000/10 (60%)]	ERM loss: 0.918866	Grad penalty: -0.000012
# First 20 logits [ 1.99986     0.38554585  1.1543294   1.5608395  -2.682968   -3.1385925
#   1.0863836   1.5468405   1.7935586   1.8109803  -1.5748799   0.8171036
#   3.3150358   1.2833207  -0.525015    1.4815297   1.1016748   0.33773923
#  -0.5045754  -2.1245959 ]
# Train Epoch: 16 [16000/10 (80%)]	ERM loss: 0.914323	Grad penalty: 0.002808
# First 20 logits [-0.2143551  -2.6963093  -3.727401    0.20896369  2.131825    3.0500855
#   0.51541215  1.1923481   2.224284   -1.2230041  -0.6477665   2.0635352
#  -1.052197   -0.05028926  1.5722319  -1.7364225  -3.3161073  -0.552521
#   2.5561042   2.0601194 ]
#
# Performance on train1 set: Average loss: 0.4746, Accuracy: 15275/20000 (76.38%)
#
#
# Performance on train2 set: Average loss: 0.4259, Accuracy: 15649/20000 (78.25%)
#
#
# Performance on test set: Average loss: 0.9510, Accuracy: 10550/20000 (52.75%)
#
# Using penalty multiplier 93.05040638761433
# Train Epoch: 17 [0/10 (0%)]	ERM loss: 0.899484	Grad penalty: 0.002373
# First 20 logits [-1.7139525   0.42025542 -2.7576127  -2.930441    1.5469093   0.5490151
#   2.2566886   0.5330286   0.6016191   1.1056414  -2.6054804   2.0441597
#   2.2680395  -1.1920887   0.7768891  -3.2784803   0.27983218 -0.36048198
#  -0.10822062 -3.3607302 ]
# Train Epoch: 17 [4000/10 (20%)]	ERM loss: 0.915812	Grad penalty: 0.000222
# First 20 logits [ 1.8820524   2.3538115   0.16447777  0.20708416  1.7422323  -2.0066485
#   2.1838558   0.30082697  1.4609134   1.9890513  -1.2312136   2.1944392
#  -2.0378628  -0.49637985 -2.1941977   1.2130299  -0.0957848  -1.5360202
#   1.1666849  -0.82120997]
# Train Epoch: 17 [8000/10 (40%)]	ERM loss: 0.927942	Grad penalty: 0.002686
# First 20 logits [ 1.7368839  -0.43968534  0.20270598  1.990944   -3.268961    0.77223444
#   0.93758565  1.2684648   0.5634318   2.576725    1.0605642   3.2946644
#   1.3415298  -2.3084097  -2.1333334   2.618587   -2.740159    2.4496105
#   1.5682017   2.1562572 ]
# Train Epoch: 17 [12000/10 (60%)]	ERM loss: 0.906379	Grad penalty: 0.000691
# First 20 logits [-2.9857185  -0.33440658 -2.2474124  -2.1063566  -3.7353597   1.932131
#   2.736909    2.7832189  -3.8416018   1.697876    0.893014   -2.8024416
#  -1.8758081  -2.237648   -3.2320733  -0.635282   -1.0832746  -1.557214
#   2.3089619  -2.8019853 ]
# Train Epoch: 17 [16000/10 (80%)]	ERM loss: 0.896924	Grad penalty: 0.000151
# First 20 logits [ 2.6449306  -2.2796504  -0.26675844 -1.21626     1.539891   -3.4351811
#  -3.5689282  -1.0633342  -3.2188418  -2.6036124   3.1424963  -0.01448205
#   1.928926    1.1238389  -0.17207195 -2.9628782   0.4040423  -1.8428679
#  -2.315892    0.33056238]
#
# Performance on train1 set: Average loss: 0.4758, Accuracy: 15436/20000 (77.18%)
#
#
# Performance on train2 set: Average loss: 0.4154, Accuracy: 15919/20000 (79.59%)
#
#
# Performance on test set: Average loss: 1.0606, Accuracy: 9601/20000 (48.01%)
#
# Using penalty multiplier 101.96145121984944
# Train Epoch: 18 [0/10 (0%)]	ERM loss: 0.898446	Grad penalty: 0.001982
# First 20 logits [ 1.6206349  -1.1106974   1.3705323   2.1635387   0.9428736   0.36969742
#  -3.9705622   0.22306985 -2.583545   -0.76236695  0.25312525 -2.4031272
#  -1.1894289   1.2308965  -0.18302959  0.53566074 -3.8594744  -0.27446792
#  -3.4600124   1.4773968 ]
# Train Epoch: 18 [4000/10 (20%)]	ERM loss: 0.886207	Grad penalty: 0.000885
# First 20 logits [ 1.0966651   1.9988415  -0.8543502   1.9791281   0.9038714  -1.398166
#   0.55578065  1.5001321  -0.45081836 -2.2193196  -2.4563582   2.7708192
#   2.2605345   0.94923913 -3.3026676  -2.9405286  -0.05696873 -2.2376237
#   2.1332433  -0.52389646]
# Train Epoch: 18 [8000/10 (40%)]	ERM loss: 0.921788	Grad penalty: 0.000758
# First 20 logits [ 0.87942195  1.7821376   1.1397676  -0.4703163  -0.7931227   3.0118423
#  -2.795804    0.6342214  -1.6211698  -2.9802256   2.6675572   2.5876193
#  -1.1425331  -0.6074567  -2.994433    0.78982025  2.0413196   1.4295058
#   1.7239244   1.3432279 ]
# Train Epoch: 18 [12000/10 (60%)]	ERM loss: 0.960966	Grad penalty: -0.000043
# First 20 logits [-2.4994454   0.24395174  0.5417043   1.2301604   0.47856897 -2.6357937
#   0.8842843   2.4714413   1.4433696   1.914635   -1.9840797  -2.6039455
#   1.3351237  -2.1005268   1.9093564  -2.4423728  -1.3602884  -2.5014796
#  -2.3292806   2.1490135 ]
# Train Epoch: 18 [16000/10 (80%)]	ERM loss: 0.962894	Grad penalty: 0.001113
# First 20 logits [-1.9921283  -1.0011811   0.44369173  0.96662754 -0.64640117 -2.5567186
#   0.16152246  2.4089658  -0.29665023  0.8385114  -0.98244506  2.3352318
#   1.6562506   1.5499514   0.6765036  -0.40382302 -2.385887    2.5746677
#   2.3943222  -3.5270753 ]
#
# Performance on train1 set: Average loss: 0.4811, Accuracy: 15195/20000 (75.97%)
#
#
# Performance on train2 set: Average loss: 0.4421, Accuracy: 15443/20000 (77.22%)
#
#
# Performance on test set: Average loss: 0.9138, Accuracy: 11010/20000 (55.05%)
#
# Using penalty multiplier 111.17464760577515
# Train Epoch: 19 [0/10 (0%)]	ERM loss: 0.917129	Grad penalty: 0.000807
# First 20 logits [ 0.2932894   1.6282443   1.4113214  -0.74586755 -3.6927774   0.6865266
#   0.67369    -2.7741854   1.447484   -2.8647301   0.62758404 -3.0456882
#  -1.1467745  -1.2348242   2.5597477   2.6138327   2.2047193   0.70730585
#  -3.0820086   1.5069053 ]
# Train Epoch: 19 [4000/10 (20%)]	ERM loss: 0.912376	Grad penalty: 0.001234
# First 20 logits [ 0.98279506  2.0864575  -1.7970604  -1.4182914   0.94868845  1.6004179
#   0.8687464   1.5043521  -3.7681036  -1.5135839  -2.0944555  -2.1313343
#   2.8044431   1.6382947  -0.42621204  2.4142718  -2.7468317  -2.2087672
#  -0.7945009   1.5717027 ]
# Train Epoch: 19 [8000/10 (40%)]	ERM loss: 0.897424	Grad penalty: 0.000069
# First 20 logits [ 0.41305408  1.5316079   1.4539685  -2.8528235   2.441789   -1.6172478
#  -0.18814574 -3.4462914   0.07617891 -2.9320147   1.997468   -1.0268843
#   0.6661503  -2.5579472  -0.68610686 -2.8300123  -0.3718416   0.5221417
#  -2.4709811  -0.4382108 ]
# Train Epoch: 19 [12000/10 (60%)]	ERM loss: 0.876254	Grad penalty: 0.000331
# First 20 logits [-0.19265231  2.172423    1.8299588   1.3634413  -1.7703602  -2.4169686
#   1.4324591  -2.1825874   1.9178848  -3.1442366   2.418796   -2.4776964
#   2.3434646   1.0133113  -0.43093342  0.3759184   0.27602288  1.0058154
#   0.5848668   3.1915038 ]
# Train Epoch: 19 [16000/10 (80%)]	ERM loss: 0.874524	Grad penalty: 0.002500
# First 20 logits [-2.5297778  -4.071056    2.3681846   3.1459646  -2.9785924   0.94289637
#   0.01238463 -2.0466883  -1.8217232  -1.2144353   0.93624336  1.6187618
#   1.7898124  -0.49918872 -0.11418883 -3.5201302   3.3672018   2.4568436
#   0.9464863  -0.71771795]
#
# Performance on train1 set: Average loss: 0.4690, Accuracy: 15427/20000 (77.14%)
#
#
# Performance on train2 set: Average loss: 0.4201, Accuracy: 15691/20000 (78.45%)
#
#
# Performance on test set: Average loss: 0.9979, Accuracy: 10547/20000 (52.73%)
#
# Using penalty multiplier 120.6835267309033
# Train Epoch: 20 [0/10 (0%)]	ERM loss: 0.892760	Grad penalty: 0.000670
# First 20 logits [-2.8537152   2.1904106  -3.3329928   2.2191856   0.8158806   0.5956985
#  -0.0290545   2.3987124   0.24426323  1.8885521  -1.8703598  -3.1030142
#  -4.0355515   0.7337589   1.5023433   1.6698233  -1.0877594  -2.9871278
#  -1.0690669  -0.71716285]
# Train Epoch: 20 [4000/10 (20%)]	ERM loss: 0.909627	Grad penalty: 0.000701
# First 20 logits [ 0.5432379   2.0214198  -3.6603272   2.6977265  -3.383399   -0.71572095
#   0.9804546  -2.976537    1.5480022  -1.5305109  -2.1619694  -2.6657498
#   0.9181863   1.4818633   2.2958224   1.5406412  -0.99404675  1.6097767
#  -0.41353953  1.9760062 ]
# Train Epoch: 20 [8000/10 (40%)]	ERM loss: 0.916656	Grad penalty: 0.000292
# First 20 logits [-1.2393782   0.5229527  -2.8643174   0.794248    0.69428676  1.2446768
#   0.59411156 -1.4182224   1.7020888   2.522599    0.89283085 -0.72984236
#  -1.0505269   0.7961968   0.4278193   0.6140114  -0.91669333 -0.4547711
#   1.9617378   1.0172663 ]
# Train Epoch: 20 [12000/10 (60%)]	ERM loss: 0.911077	Grad penalty: 0.001040
# First 20 logits [ 1.7944149e+00  1.8404332e-01  2.7267647e+00  2.4261537e+00
#  -3.9964209e+00  1.7086648e+00 -3.0966840e+00  1.0366597e+00
#   2.8722878e+00 -2.1573976e-03  1.1880909e+00 -2.0868378e+00
#  -4.0820651e+00  1.6293020e+00  1.2418300e+00  3.3207667e-01
#  -4.6589237e-01 -9.8316532e-01 -4.1821992e-01  1.6344460e+00]
# Train Epoch: 20 [16000/10 (80%)]	ERM loss: 0.903559	Grad penalty: -0.000125
# First 20 logits [ 1.7750474  -2.0044296   1.1610291  -0.60854495  1.3123859  -2.0261316
#   0.20643301 -0.37357706 -1.6171771  -1.3227359   1.8901855   0.6521642
#   0.7215872   1.1393191   2.8315306  -2.7506766  -2.461737   -2.564655
#   0.23814659 -3.3717062 ]
#
# Performance on train1 set: Average loss: 0.4646, Accuracy: 15417/20000 (77.08%)
#
#
# Performance on train2 set: Average loss: 0.4157, Accuracy: 15744/20000 (78.72%)
#
#
# Performance on test set: Average loss: 0.9772, Accuracy: 10315/20000 (51.58%)
#
# Using penalty multiplier 130.48208013457565
# Train Epoch: 21 [0/10 (0%)]	ERM loss: 0.896083	Grad penalty: 0.000945
# First 20 logits [ 2.8144498e+00  1.7881738e+00  1.0753374e+00 -1.2588501e-03
#   6.0274088e-01  1.8717165e+00  2.4385006e+00 -1.3343629e+00
#   1.7821506e+00  3.0305142e+00  2.1403108e+00  2.3501959e+00
#  -2.5824008e+00  2.1596587e+00  2.9998477e+00  1.6449003e+00
#   1.2368050e+00 -6.8964970e-01 -2.6896813e+00 -2.0577345e+00]
# Train Epoch: 21 [4000/10 (20%)]	ERM loss: 0.893097	Grad penalty: 0.003085
# First 20 logits [ 0.5046365   1.2566248   2.4175732   2.0551507   2.6586626   2.0050504
#  -3.4338076  -0.04874524  3.2830708  -0.87608194 -0.64055574  2.9884293
#  -1.0909822   2.6758277   2.7054207  -0.3774165   2.0978403  -1.0275191
#   2.1826692  -2.6644242 ]
# Train Epoch: 21 [8000/10 (40%)]	ERM loss: 0.853669	Grad penalty: 0.000661
# First 20 logits [-3.8186884e-01  2.4858797e-01 -2.6355364e+00  7.0701510e-01
#   1.7924321e+00 -1.0134901e-01  4.6994644e-01 -2.6574974e+00
#  -3.8576226e+00 -7.0465082e-01 -1.6432779e-01  1.9293778e+00
#   6.4538047e-04  1.1559963e+00 -6.5900171e-01  5.6266636e-01
#   1.6954560e+00  1.6857898e+00  1.2647231e+00 -3.6046963e+00]
# Train Epoch: 21 [12000/10 (60%)]	ERM loss: 0.895814	Grad penalty: 0.001331
# First 20 logits [ 0.01972665  0.91168696 -1.4926076  -1.4840441  -3.042878   -0.76919764
#  -0.209609   -0.24967381 -0.3527424   1.2852222  -3.347953   -4.0472264
#  -0.11650599 -0.5878673  -1.9047868   0.35405517 -3.1386516   1.214389
#  -2.5441382  -0.8961605 ]
# Train Epoch: 21 [16000/10 (80%)]	ERM loss: 0.947122	Grad penalty: 0.000155
# First 20 logits [-1.5823449  -3.232027    0.31886774  2.678254   -3.416462   -0.12822342
#  -1.8450593  -3.811744    0.3196919  -1.0247335   1.3114204   0.39646474
#   0.50240016 -1.8416449  -3.5765243   0.5498982  -1.5249192   1.5129654
#  -2.6403503  -2.0109725 ]
#
# Performance on train1 set: Average loss: 0.4950, Accuracy: 15179/20000 (75.89%)
#
#
# Performance on train2 set: Average loss: 0.4669, Accuracy: 15243/20000 (76.22%)
#
#
# Performance on test set: Average loss: 0.8649, Accuracy: 11763/20000 (58.81%)
#
# Using penalty multiplier 140.56470623764733
# Train Epoch: 22 [0/10 (0%)]	ERM loss: 0.963975	Grad penalty: -0.000134
# First 20 logits [-0.3185189  -2.2274725   1.4047874  -0.48186195 -2.096338    0.7720855
#  -0.5349509  -1.8427014   2.3306725   0.40961376  0.596347   -0.4702053
#  -1.0667936  -0.65639    -0.4737069  -1.41954    -0.5689288   1.3303243
#  -2.9096415  -2.6888514 ]
# Train Epoch: 22 [4000/10 (20%)]	ERM loss: 0.958928	Grad penalty: 0.000093
# First 20 logits [-1.0674592   1.4989613  -1.7930938  -1.9984823  -1.3077545  -1.7893314
#   0.77716637  0.3864221  -2.31731    -1.4554895  -3.5848346   0.32323498
#  -0.8672997   1.2306902  -0.9909519  -2.6668055  -1.1075755  -0.9833348
#  -3.0980814  -2.700056  ]
# Train Epoch: 22 [8000/10 (40%)]	ERM loss: 0.970109	Grad penalty: -0.000071
# First 20 logits [ 2.3264399   0.6718225  -0.9881545  -1.181677   -1.605987   -2.3991773
#   1.4005908  -2.065255    1.000983    0.6926418  -0.29165706  1.9105324
#   0.7029932  -2.1105087   0.6157678  -0.10603812  1.9528712   0.95526326
#  -1.3358     -2.7501745 ]
# Train Epoch: 22 [12000/10 (60%)]	ERM loss: 0.932095	Grad penalty: -0.000229
# First 20 logits [ 2.0084245  -1.9006124   0.6934272   2.3742301   0.5891306  -3.252413
#  -0.8182519   1.3778301   0.97837436 -0.38025275  2.7533977  -1.7576752
#  -0.59577507  0.03790712 -1.9872755  -2.5267591  -0.7300743  -3.4008825
#   0.7544305  -2.2601278 ]
# Train Epoch: 22 [16000/10 (80%)]	ERM loss: 0.926786	Grad penalty: 0.000646
# First 20 logits [-2.7692866  -0.43163106  1.0343533  -2.0900033   1.5523641   1.9137101
#  -1.4666542   3.348621   -3.6212487   2.2042108   3.511702   -1.5893927
#  -0.814515    1.4259105  -2.0038333   1.6071324  -2.4446871  -0.08015341
#  -2.8488235   3.0250087 ]
#
# Performance on train1 set: Average loss: 0.4503, Accuracy: 15651/20000 (78.25%)
#
#
# Performance on train2 set: Average loss: 0.3844, Accuracy: 16192/20000 (80.96%)
#
#
# Performance on test set: Average loss: 1.0939, Accuracy: 8698/20000 (43.49%)
#
# Using penalty multiplier 150.92616526686473
# Train Epoch: 23 [0/10 (0%)]	ERM loss: 0.850644	Grad penalty: 0.001429
# First 20 logits [ 2.0715613   1.5936533  -2.1711946  -0.26476866  2.3503861   2.6147828
#  -2.9094205  -2.0004883  -2.0049076   3.006011   -2.84766     1.6257862
#  -0.2287122  -3.5481758  -1.234229    2.5807872   2.935051   -0.28662348
#   2.6965303   1.6036162 ]
# Train Epoch: 23 [4000/10 (20%)]	ERM loss: 0.819131	Grad penalty: 0.003943
# First 20 logits [ 0.30592597  0.9537174  -0.4712963  -3.5997014   1.9865831   1.0834284
#   1.5940605   0.99897164 -1.8890208  -3.8634534   1.3912005  -2.7038336
#  -1.6579683  -2.0802674  -0.28576684  1.9522281   2.2429113  -0.5397628
#  -2.5282965   1.8068382 ]
# Train Epoch: 23 [8000/10 (40%)]	ERM loss: 0.848791	Grad penalty: 0.000455
# First 20 logits [-1.9345169  -3.6482475  -0.98614377  0.86298025 -3.2326047   2.4239485
#  -2.250006   -0.7223224  -3.7710457  -3.1757405  -4.3148184   1.385844
#  -1.0229441   2.4228432  -2.1430411   1.0793757  -0.14214218  0.21953359
#   0.2497853   1.49864   ]
# Train Epoch: 23 [12000/10 (60%)]	ERM loss: 0.882386	Grad penalty: 0.000870
# First 20 logits [ 1.873489    2.05431     1.6790344   0.4203792  -0.59321797  0.52073514
#   1.7045976  -1.538484    1.007143   -3.9629443   1.2783841  -0.6333345
#   3.3383512  -3.001308    1.9059368  -2.792023   -0.14544368 -3.579644
#  -1.9706243   1.4360758 ]
# Train Epoch: 23 [16000/10 (80%)]	ERM loss: 0.934882	Grad penalty: 0.000129
# First 20 logits [-1.2215382   0.7006546  -1.6635516  -2.9843452  -0.05539007 -0.60771674
#   1.835497    0.15530592 -2.0488796   1.2711507  -1.3300321  -2.6948025
#   2.0338528   1.1498197   1.5417632  -0.51519626 -3.4668586   2.0317042
#  -1.8442998  -2.708133  ]
#
# Performance on train1 set: Average loss: 0.4881, Accuracy: 15164/20000 (75.82%)
#
#
# Performance on train2 set: Average loss: 0.4608, Accuracy: 15243/20000 (76.22%)
#
#
# Performance on test set: Average loss: 0.8754, Accuracy: 11806/20000 (59.03%)
#
# Using penalty multiplier 161.56154094425278
# Train Epoch: 24 [0/10 (0%)]	ERM loss: 0.957962	Grad penalty: -0.000192
# First 20 logits [ 2.6851852   1.691174   -0.4616187   1.1207511  -3.698957   -0.8269721
#  -2.600861    2.4965541  -0.9170015   0.3329041   0.13478136  0.878875
#   0.32074878 -0.4282486   0.8532887   1.4510624   1.930296    1.7625151
#   0.4148629   2.778761  ]
# Train Epoch: 24 [4000/10 (20%)]	ERM loss: 0.980810	Grad penalty: -0.000065
# First 20 logits [ 1.0688835  -2.1964633   2.6028106  -1.5662777   2.0144675   3.1491697
#   0.47259948 -0.9388318  -0.60369575 -1.145813   -2.9946666  -2.5105913
#  -3.026872   -0.28535336  1.9265636   2.3449605   1.4866854  -0.89960754
#   2.2951388   2.4373486 ]
# Train Epoch: 24 [8000/10 (40%)]	ERM loss: 0.964192	Grad penalty: 0.000533
# First 20 logits [ 1.3886513  -0.7098891   1.8918827  -1.0208486  -1.2481374  -0.442382
#  -0.79848146  1.0679742  -1.8604871  -1.5350425  -0.66247994  2.5667634
#  -2.097283    1.200373    0.53393626 -1.8458514  -0.00439156  0.93445426
#   0.07910393  0.96147925]
# Train Epoch: 24 [12000/10 (60%)]	ERM loss: 0.912189	Grad penalty: 0.001389
# First 20 logits [ 0.07138464 -3.1158109  -0.62480867  1.9281949   1.5313369   2.183142
#   1.7826937   1.0540124   2.5800753   0.31551188  0.4967192  -0.8386121
#   1.3471683   1.2990745  -0.85539454  1.0329233   1.1777924  -0.4390408
#  -1.0293294   0.92483854]
# Train Epoch: 24 [16000/10 (80%)]	ERM loss: 0.948493	Grad penalty: 0.001517
# First 20 logits [ 1.623079   -1.8084239  -2.017417    0.28764603  2.2643085   1.5815982
#   0.36782423 -3.6320736   2.1940818   2.3799918   0.39538243  0.2756295
#   2.0209885   1.9562525   2.696201    2.4150414   0.40722495  2.5635886
#   3.073639    1.0393028 ]
#
# Performance on train1 set: Average loss: 0.4779, Accuracy: 15199/20000 (76.00%)
#
#
# Performance on train2 set: Average loss: 0.4413, Accuracy: 15369/20000 (76.84%)
#
#
# Performance on test set: Average loss: 0.9246, Accuracy: 11233/20000 (56.16%)
#
# Using penalty multiplier 172.4662076826519
# Train Epoch: 25 [0/10 (0%)]	ERM loss: 0.892702	Grad penalty: 0.001874
# First 20 logits [ 2.1066499  -2.0062294  -3.1486328   0.11375073 -0.99864686 -0.8726847
#  -1.3330456  -1.4936413   1.0213604   1.6414088  -1.9921032   1.1974171
#  -0.3931489   2.557736    2.18717    -0.41262627  0.87557304 -0.62663627
#   0.6368201  -1.6317364 ]
# Train Epoch: 25 [4000/10 (20%)]	ERM loss: 0.916941	Grad penalty: 0.000060
# First 20 logits [-3.57229    -1.725853   -1.6349052   2.5064137  -0.44143748  1.5205871
#  -1.274171   -0.6705151  -2.0428417   2.5450523   2.6579945  -0.82345057
#   2.7380087   1.2041117   0.97464114 -2.191809    3.1090178  -0.37123415
#   1.2755607  -4.070481  ]
# Train Epoch: 25 [8000/10 (40%)]	ERM loss: 0.908039	Grad penalty: -0.000111
# First 20 logits [-2.18242    -1.0617723  -2.083352    1.8901653  -2.6874216  -0.0384212
#   0.48600852 -1.2338742   2.3087847  -4.2993684   0.5653919   2.1438582
#   0.19204864  1.1381012  -1.8561362  -3.5078154  -2.187323   -1.986043
#  -0.397688    1.135978  ]
# ...
#
# Using penalty multiplier 195.06619950773612
# Train Epoch: 27 [0/10 (0%)]	ERM loss: 0.973074	Grad penalty: 0.000089
# First 20 logits [-2.167008   -2.287714    1.3725275   1.8247582   0.81190664 -0.96604896
#   1.3829194  -2.4700685  -1.2873375   0.7760997  -2.8488276  -3.3476295
#  -0.19855757 -2.4627757   0.13878071  1.0921581  -3.7737272  -2.260056
#  -0.89989346 -0.88228613]
# Train Epoch: 27 [4000/10 (20%)]	ERM loss: 0.960289	Grad penalty: 0.000071
# First 20 logits [-4.2453465  -1.1002688  -4.0495114  -0.02004807  1.2505385   1.5594201
#   0.25824463  1.6899438   1.2644032   0.41883984  0.9409937  -2.2212734
#  -1.6798166   0.9858873   2.0795453   2.3081248   1.18782     0.5011363
#  -1.7480342   1.680999  ]
# Train Epoch: 27 [8000/10 (40%)]	ERM loss: 0.915340	Grad penalty: 0.001014
# First 20 logits [-0.99319136  1.6826277   1.6572268  -0.47607994  1.5053877   0.1715895
#  -2.8798337  -0.9746895   1.7128141   0.60534066 -3.042505    1.4842567
#   0.25563282 -2.4983962   0.46021718 -0.30471027 -0.04380949  2.0632794
#  -3.2238352  -1.1541092 ]
# Train Epoch: 27 [12000/10 (60%)]	ERM loss: 0.879564	Grad penalty: 0.000960
# First 20 logits [-0.8048445  -1.0898983   1.269012   -1.835371    0.15898868 -3.372895
#   2.9050722   2.2273958   2.3074114   1.1125001  -2.425761   -4.066797
#   1.5009866   0.9633007   2.5634446   0.9437149   1.2816961  -1.9987392
#   2.5148153   0.76135284]
# Train Epoch: 27 [16000/10 (80%)]	ERM loss: 0.891510	Grad penalty: 0.000877
# First 20 logits [-0.8679625   0.06072295  1.6416056  -4.6010003  -0.27817997  1.8353766
#   3.0224466   0.27421227  1.8777225   2.3893216   1.7165525  -4.001227
#  -2.3986473   2.1335714  -1.7322333   1.1965044   0.945392    0.90560305
#   2.6878047   2.3520036 ]
#
# Performance on train1 set: Average loss: 0.4711, Accuracy: 15360/20000 (76.80%)
#
#
# Performance on train2 set: Average loss: 0.4329, Accuracy: 15573/20000 (77.86%)
#
#
# Performance on test set: Average loss: 0.9418, Accuracy: 10552/20000 (52.76%)
#
# Using penalty multiplier 206.75349046081027
# Train Epoch: 28 [0/10 (0%)]	ERM loss: 0.897068	Grad penalty: 0.001955
# First 20 logits [ 1.0380311   0.39382547  1.9254302   1.0044048  -3.358063    2.0298624
#  -0.36498436 -0.66504765  2.2917378  -1.6968219   1.6549702  -0.8016645
#   0.7660555   0.8901115   0.675559    2.2536566   1.8812771  -1.9933522
#   2.0975492  -0.15757164]
# Train Epoch: 28 [4000/10 (20%)]	ERM loss: 0.936903	Grad penalty: 0.000107
# First 20 logits [ 2.0904582   0.33024356 -3.05177    -1.8236454  -2.2438989  -2.2337961
#  -1.3406422  -0.7192984  -3.340004    0.02859234 -4.88058     1.8773078
#   0.5025946  -1.6451622  -1.4953829   2.3800874  -1.4842829  -1.4645545
#   1.9789282  -1.2391394 ]
# Train Epoch: 28 [8000/10 (40%)]	ERM loss: 0.932609	Grad penalty: 0.000559
# First 20 logits [ 1.6769245  -0.2765875   2.0815716   1.5144565  -1.8665681   1.356768
#  -2.314181   -2.105399    0.9783712  -1.5615269   2.4265122  -0.4494216
#   2.0755365  -0.38842142 -1.0651977  -1.7953411  -0.14389677  0.6723062
#   2.6408303   2.143003  ]
# Train Epoch: 28 [12000/10 (60%)]	ERM loss: 0.924196	Grad penalty: -0.000078
# First 20 logits [-2.9421842  -2.8776712   1.7190652   1.7037005   2.3611145  -1.9619687
#  -0.25916454 -1.2415745  -0.46207842  1.27933    -0.8034693   0.03964504
#  -1.725698    1.7311319   0.7328743  -3.6078491  -4.0820556   0.8196014
#   1.2721815  -1.6566219 ]
# Train Epoch: 28 [16000/10 (80%)]	ERM loss: 0.917722	Grad penalty: 0.000136
# First 20 logits [ 0.3173949   1.1711713   1.1192281   0.785597    0.870342    1.9649
#   0.78748727  0.819064   -4.5521965   1.6108062  -2.6582086   2.215115
#  -3.807222   -1.4976158   2.5140903   0.30688918 -2.820364    1.5227835
#  -2.8008053   1.4302397 ]
#
# Performance on train1 set: Average loss: 0.4761, Accuracy: 15393/20000 (76.97%)
#
#
# Performance on train2 set: Average loss: 0.4411, Accuracy: 15498/20000 (77.49%)
#
#
# Performance on test set: Average loss: 0.9553, Accuracy: 10943/20000 (54.72%)
#
# Using penalty multiplier 218.69396402795164
# Train Epoch: 29 [0/10 (0%)]	ERM loss: 0.913695	Grad penalty: 0.000109
# First 20 logits [-1.0777189  -0.10360895 -2.140427   -0.49465224 -0.26610067  2.0468671
#  -2.1938827  -1.2357587   0.04725023  0.9714179  -1.163628   -3.452141
#  -3.2315972  -0.7201123  -1.839852   -3.7400155  -4.4088264  -0.6090096
#   0.3980482  -2.5336416 ]
# Train Epoch: 29 [4000/10 (20%)]	ERM loss: 0.899443	Grad penalty: 0.001039
# First 20 logits [ 1.496617   -3.2899742  -1.4960654  -3.110002   -1.1891423   0.99595314
#  -3.382041    2.0071945  -2.1675     -1.003946    0.9903521   2.8013935
#   1.0273073  -2.114985   -1.8977982   1.5635597  -1.7560014   0.8936541
#  -4.655152   -3.1368198 ]
# Train Epoch: 29 [8000/10 (40%)]	ERM loss: 0.941922	Grad penalty: 0.000447
# First 20 logits [ 1.2631456  -4.218432   -4.4225726   1.0102947  -3.5284252  -1.6048487
#   1.8833077  -2.7838597   1.4699209  -0.605013   -0.50130075 -0.8083299
#   0.99725056 -2.60498     2.7547014  -1.3349999  -1.2327774   0.5622487
#   2.4706078   2.1164875 ]
# Train Epoch: 29 [12000/10 (60%)]	ERM loss: 0.952785	Grad penalty: -0.000020
# First 20 logits [ 2.11710668e+00 -4.11135340e+00  1.20990479e+00 -2.36519980e+00
#  -2.09262061e+00  2.16507936e+00 -2.55950475e+00  2.58118558e+00
#   2.10858369e+00  1.37066460e+00  2.06965953e-04 -1.75698149e+00
#   8.47018301e-01 -2.90832639e-01 -2.51474786e+00 -2.52582431e+00
#   1.96057534e+00 -5.38069546e-01  1.24221385e-01 -2.66392803e+00]
# Train Epoch: 29 [16000/10 (80%)]	ERM loss: 0.942574	Grad penalty: 0.000506
# First 20 logits [-3.9374273   0.32489187  1.4088117   1.6411455   0.04597551  1.4522793
#   1.2811216   2.2190769  -2.497361   -1.2276365  -1.2604429  -0.14891736
#  -2.3601863  -1.7966927  -1.1073692  -0.729369   -3.1909091  -0.7625432
#  -2.9675963   2.2989204 ]
#
# Performance on train1 set: Average loss: 0.4810, Accuracy: 15216/20000 (76.08%)
#
#
# Performance on train2 set: Average loss: 0.4557, Accuracy: 15245/20000 (76.22%)
#
#
# Performance on test set: Average loss: 0.9084, Accuracy: 11647/20000 (58.23%)
#
# Using penalty multiplier 230.88409022178243
# Train Epoch: 30 [0/10 (0%)]	ERM loss: 0.918820	Grad penalty: -0.000075
# First 20 logits [-4.0344057   1.6159253  -1.7623112  -0.3114961   1.2949684   0.72836715
#  -2.538523    1.7297894   3.2107248  -2.8425722   1.7250292   1.8725326
#  -1.2365104  -3.15755    -0.2937337   1.5167478   1.8905112   0.12998888
#   1.2820257  -1.5953496 ]
# Train Epoch: 30 [4000/10 (20%)]	ERM loss: 0.891381	Grad penalty: -0.000400
# First 20 logits [-1.3981310e+00 -1.3079524e+00 -1.0894947e-03  2.1897185e+00
#   2.8665960e+00  9.0592432e-01  2.7588911e+00  1.9717253e+00
#  -2.3027923e+00 -2.2379484e+00  2.4750521e+00  7.5341511e-01
#  -9.2589295e-01  6.3250017e-01  2.1689193e+00 -1.8437654e-01
#  -2.1985760e+00 -3.1526248e+00 -2.3301287e+00 -2.7807443e+00]
# Train Epoch: 30 [8000/10 (40%)]	ERM loss: 0.888252	Grad penalty: 0.000119
# First 20 logits [-2.752905   -1.8436401  -0.8886664  -0.07973965 -1.1924622   0.42484808
#  -0.33049828  0.9198333   0.14887059 -1.418883    1.8269799   0.8061397
#  -3.0355906   0.87917554 -3.8696856   2.5462465   1.3319285  -2.4710314
#  -0.18706161 -1.7038431 ]
# Train Epoch: 30 [12000/10 (60%)]	ERM loss: 0.876265	Grad penalty: -0.000584
# First 20 logits [-0.72527134  0.6258407   3.5443778  -2.881916    2.7182498  -0.35356015
#   0.42922205 -2.6609225   2.1100738  -1.8877324   0.29007423  2.0332084
#   2.360319    1.7751839  -1.0094948  -0.7119795   0.54944617  0.6579679
#   0.64335066  0.6202163 ]
# Train Epoch: 30 [16000/10 (80%)]	ERM loss: 0.887924	Grad penalty: 0.000719
# First 20 logits [ 7.5225502e-01  2.6946535e+00 -4.7311187e-05  1.0940218e+00
#  -2.9057660e+00  8.9982146e-01  2.2930937e+00 -3.0650041e-01
#   1.9177774e-01  3.0374992e+00  1.4872873e+00  2.9484320e+00
#   2.5400505e+00 -6.3145763e-01  2.5437453e+00  2.7117367e+00
#   3.4235911e+00 -2.6436377e+00 -1.9434471e+00  2.5606868e+00]
#
# Performance on train1 set: Average loss: 0.4649, Accuracy: 15407/20000 (77.03%)
#
#
# Performance on train2 set: Average loss: 0.4238, Accuracy: 15663/20000 (78.31%)
#
#
# Performance on test set: Average loss: 0.9939, Accuracy: 10494/20000 (52.47%)
#
# Using penalty multiplier 243.3205055522631
# Train Epoch: 31 [0/10 (0%)]	ERM loss: 0.909230	Grad penalty: 0.000976
# First 20 logits [-0.20858009 -1.6525724   0.93391496 -3.2148502  -0.9794723  -0.12774421
#  -3.3970926   2.6296344  -2.0673587  -2.5633228   2.2866695   0.09392478
#  -1.6187996   1.705656    1.4666675   0.313876    1.9063978  -0.5281613
#  -0.7000671   3.7045143 ]
# Train Epoch: 31 [4000/10 (20%)]	ERM loss: 0.928447	Grad penalty: 0.000901
# First 20 logits [ 0.8315179  -2.2525117   1.8508698  -0.7448693   1.898119    0.05991228
#   1.9556905  -1.420887   -0.63026935  2.347519   -3.1317093  -0.8278812
#  -1.4495475  -0.9039125   0.871796    2.0288966  -1.3074718  -0.36184052
#  -0.0622604  -3.0817788 ]
# Train Epoch: 31 [8000/10 (40%)]	ERM loss: 0.949795	Grad penalty: 0.000505
# First 20 logits [ 1.7980199   0.87292945  2.326693   -2.1374767  -1.0924734   1.8081188
#   2.31555     1.5167997   1.1594276  -1.2844269   2.4763174   2.127376
#  -3.0951362  -1.3418992   0.7205293  -2.0749645   2.0081697   3.2853758
#  -0.12927221  2.0907729 ]
# Train Epoch: 31 [12000/10 (60%)]	ERM loss: 0.953368	Grad penalty: 0.000097
# First 20 logits [-0.48959607  2.618513   -0.896467   -0.99251467 -1.5698     -2.7327542
#   0.53379387  2.208911    1.8179802  -1.578329   -2.2999034  -0.28820914
#   0.7331898  -3.4146981  -0.5101946   2.2068815   1.987691   -2.1821418
#   1.2521142   0.41079032]
# Train Epoch: 31 [16000/10 (80%)]	ERM loss: 0.926739	Grad penalty: 0.001031
# First 20 logits [ 2.4806166   1.1321579  -1.0907321   1.0484205  -1.6831423  -0.19880992
#  -0.948958    1.8212215  -2.6016273  -0.7988568   0.99999654  0.3230952
#   1.5198957  -1.1389456  -2.9745457   0.8180325  -1.7607458  -1.0035211
#  -1.0739919   0.5126317 ]
#
# Performance on train1 set: Average loss: 0.4809, Accuracy: 15246/20000 (76.23%)
#
#
# Performance on train2 set: Average loss: 0.4462, Accuracy: 15436/20000 (77.18%)
#
#
# Performance on test set: Average loss: 0.9596, Accuracy: 10719/20000 (53.59%)
#
# Using penalty multiplier 256.00000000000006
# Train Epoch: 32 [0/10 (0%)]	ERM loss: 0.963931	Grad penalty: 0.001381
# First 20 logits [-1.343613    2.429478    1.4688878   3.5352046  -4.262198   -2.1019084
#  -0.5518083   1.7479984   2.0495253  -2.863962    2.9004686  -0.8265665
#  -0.38260132  2.264231   -2.8340302   0.7217031  -1.7943438   1.8223747
#   2.0527086   3.1240547 ]
# Train Epoch: 32 [4000/10 (20%)]	ERM loss: 0.892931	Grad penalty: 0.000267
# First 20 logits [-2.9175058e-03  2.0561905e+00  1.3947262e+00  2.7242262e+00
#  -2.0969729e+00 -3.1812425e+00 -6.5600443e-01 -3.9198020e+00
#  -2.6185876e-01 -2.1895800e+00 -9.6112967e-01 -3.0611999e+00
#   2.3208203e+00  1.7048992e+00 -2.4938388e-01 -1.3519530e+00
#  -1.3172233e+00 -1.6610118e+00  1.4892995e+00  2.9334137e+00]
# Train Epoch: 32 [8000/10 (40%)]	ERM loss: 0.909708	Grad penalty: 0.000371
# First 20 logits [ 1.7562963   2.493035    2.0151541  -1.5981843   1.3238273  -1.4419179
#   2.7098997  -3.8078735   1.7695804  -3.0626628  -0.91376793  0.54590106
#  -1.0828497   2.330127    1.8092318  -1.9351199  -3.1164765  -4.166848
#   1.4298396   2.302158  ]
# Train Epoch: 32 [12000/10 (60%)]	ERM loss: 0.904333	Grad penalty: 0.000170
# First 20 logits [-1.3416426  -2.8036046  -1.6242057   0.22064862  0.53555995  2.7056603
#   1.4218382  -0.6248887  -0.05904049  2.2306175  -2.3961673   1.9085878
#   1.0578637  -0.50718784  0.9260496   2.3644137   1.5829197   2.3956876
#  -0.342419    0.51475984]
# Train Epoch: 32 [16000/10 (80%)]	ERM loss: 0.891430	Grad penalty: 0.000377
# First 20 logits [-2.4830968  -0.212968   -3.809365    0.2592255  -2.4718864  -0.16432807
#  -4.9351387  -0.3721064   0.35164967 -0.23422687 -1.456926    0.48744628
#  -1.0892926  -0.6333725  -0.93375474 -4.198264   -3.0208807  -1.3862146
#  -5.2474422  -3.0158267 ]
#
# Performance on train1 set: Average loss: 0.4808, Accuracy: 15373/20000 (76.86%)
#
#
# Performance on train2 set: Average loss: 0.4457, Accuracy: 15486/20000 (77.43%)
#
#
# Performance on test set: Average loss: 0.9765, Accuracy: 10827/20000 (54.13%)
#
# Using penalty multiplier 268.91950538814353
# Train Epoch: 33 [0/10 (0%)]	ERM loss: 0.927879	Grad penalty: -0.000172
# First 20 logits [ 1.4312862  -0.10269443 -1.887269    0.90559524 -0.19617453 -1.61353
#  -3.151882   -1.3575315   0.47018072  0.1940135   2.792432   -4.701976
#  -0.65442854  0.27314642 -1.009696    1.7675313   1.6467367   0.05666665
#  -0.95440984  2.5244367 ]
# Train Epoch: 33 [4000/10 (20%)]	ERM loss: 0.943148	Grad penalty: 0.000642
# First 20 logits [-2.4589436  -3.1716237   2.1601043   1.3143601  -1.0815982   1.3533082
#   1.4322324   1.4054072   0.467417   -0.8110338   2.463462    1.8366609
#  -4.177061   -1.2101932   0.30471295 -3.5226893  -4.160986   -0.63533634
#  -2.2866      2.6778564 ]
# Train Epoch: 33 [8000/10 (40%)]	ERM loss: 0.969743	Grad penalty: 0.000013
# First 20 logits [ 1.9924345  -0.0151448   1.2166793   0.6588235   2.3468056   0.7985709
#   0.57026863  1.6923594  -1.0235362   1.7559657  -0.06150251 -0.83242357
#  -0.00682547  0.15009856 -2.298037    0.62801564 -0.26277402  0.78870726
#  -0.43073148  1.1436036 ]
# Train Epoch: 33 [12000/10 (60%)]	ERM loss: 0.993167	Grad penalty: 0.001430
# First 20 logits [-1.415721    1.1968765  -0.7345743   1.8620864   1.5649635  -0.00517593
#  -2.4765732   0.5974258   1.0598452  -0.7544542  -2.4308884   0.7866921
#  -0.13135171  1.8259643   1.8094633   1.5070665   1.6074482  -0.8974878
#   2.364626   -3.257064  ]
# Train Epoch: 33 [16000/10 (80%)]	ERM loss: 0.884374	Grad penalty: 0.001505
# First 20 logits [ 0.5542916   0.07000427 -2.306163   -2.3299305   0.34962866 -2.2475045
#   0.5542376  -1.696537    1.070264    1.5337173   2.2569568   0.20279427
#  -4.0044413   2.322151    2.2116103   0.9439435  -2.7061174  -1.165089
#  -0.14916196  1.5550019 ]
#
# Performance on train1 set: Average loss: 0.4564, Accuracy: 15624/20000 (78.12%)
#
#
# Performance on train2 set: Average loss: 0.3963, Accuracy: 16056/20000 (80.28%)
#
#
# Performance on test set: Average loss: 1.1514, Accuracy: 9156/20000 (45.78%)
#
# Using penalty multiplier 282.07608496446403
# Train Epoch: 34 [0/10 (0%)]	ERM loss: 0.850432	Grad penalty: 0.000238
# First 20 logits [ 2.4336615  -0.01301693 -2.653265    1.4523618   2.1343477  -2.4845133
#  -0.05413615 -3.1614714   2.897413    1.2041947  -4.42767    -4.3332815
#   0.04544134 -0.25969502 -0.31877068  0.6791329  -1.330497    1.955823
#  -0.10633728  2.547791  ]
# Train Epoch: 34 [4000/10 (20%)]	ERM loss: 0.831112	Grad penalty: 0.001219
# First 20 logits [ 1.4243151   0.16955376  0.8560423   1.5615957   2.5680933   1.9152381
#   1.9755505   3.2295718   2.6312976  -0.98386973  0.6419742  -0.0871387
#  -4.1474657   1.4325752  -1.7067993  -5.1471176   1.9948605  -0.39012688
#  -0.12051744 -0.5916019 ]
# Train Epoch: 34 [8000/10 (40%)]	ERM loss: 0.948472	Grad penalty: 0.000188
# First 20 logits [-4.4015927   2.158308    2.000467    1.4554284  -1.16058     1.4169083
#   2.7487867   1.3793565   1.934931    2.2459564  -0.7016532   2.175615
#   1.1685467  -0.9181397   2.651195    2.3805172  -2.6578245   2.7824497
#   1.4378515   0.02686694]
# Train Epoch: 34 [12000/10 (60%)]	ERM loss: 1.027866	Grad penalty: 0.000414
# First 20 logits [-5.9033084e-01  1.5027356e+00 -2.0471400e-01  1.9027255e+00
#   2.9337239e-01 -1.3174117e-03 -5.6810951e-01 -1.5528798e+00
#   2.2812003e-01 -1.9580820e+00  1.8621525e+00  1.0675693e+00
#   1.5666113e+00 -1.6643964e+00 -3.9295587e-01  2.1889853e+00
#  -3.4100339e+00  1.4318000e+00 -5.6342679e-01  1.6646128e+00]
# Train Epoch: 34 [16000/10 (80%)]	ERM loss: 1.064700	Grad penalty: -0.000025
# First 20 logits [ 1.5906287  -3.3556268   0.01940646  1.7411226   1.5384563   0.4504711
#   1.9804544   2.4233074   1.9904935  -0.31072623  1.9938229  -1.0246569
#   0.12176452 -1.0822622  -1.5650338   2.2491772   0.73469687 -1.8870987
#  -2.0796034   0.42219922]
#
# Performance on train1 set: Average loss: 0.5341, Accuracy: 14566/20000 (72.83%)
#
#
# Performance on train2 set: Average loss: 0.5270, Accuracy: 14491/20000 (72.45%)
#
#
# Performance on test set: Average loss: 0.7617, Accuracy: 12489/20000 (62.45%)
#
# found acceptable values. stopping training.

# %%
model_IRM
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(20, 50, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=800, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=1, bias=True)
# )

# %% [markdown]
# ## Evaluation and Comparision

# %%
test_data = ColoredMNIST(root='./data', env='test', transform=transforms.Compose([
  transforms.ToTensor(),
  transforms.Normalize((0.1307, 0.1307, 0.), (0.3081, 0.3081, 0.3081))
]))
test_loader = torch.utils.data.DataLoader(test_data,batch_size=18, shuffle=False)
# Out:
# Colored MNIST dataset already exists

# %%
device = "cuda"
model_IRM.eval()
with torch.no_grad():
    for data, target in test_loader:
      data, target = data.to(device), target.to(device).float()
      output = model_IRM(data)
      pred = torch.where(torch.gt(output, torch.Tensor([0.0]).to(device)),
                         torch.Tensor([1.0]).to(device),
                         torch.Tensor([0.0]).to(device))  # get the index of the max log-probability
      break

# %%
# IRM
fig = plt.figure(figsize=(13, 8))
columns = 6
rows = 3
# ax enables access to manipulate each of subplots
ax = []

for i in range(columns * rows):
    img, label = test_set[i]
    pred_label = int(pred[i].cpu())
    # create subplot and append to ax
    ax.append(fig.add_subplot(rows, columns, i + 1))
    ax[-1].set_title(f"Label: {label} Pred: {pred_label}" )  # set title
    plt.imshow(img)
plt.suptitle("IRM Prediction on Test Dataset", y = 0.92)
plt.savefig("IRM Prediction on Test Dataset.png")
plt.show()  # finally, render the plot

# %%
# ERM
device = "cuda"
model_ERM.eval()
with torch.no_grad():
    for data, target in test_loader:
      data, target = data.to(device), target.to(device).float()
      output = model_ERM(data)
      pred = torch.where(torch.gt(output, torch.Tensor([0.0]).to(device)),
                         torch.Tensor([1.0]).to(device),
                         torch.Tensor([0.0]).to(device))  # get the index of the max log-probability
      break

# %%
# IRM
fig = plt.figure(figsize=(13, 8))
columns = 6
rows = 3
# ax enables access to manipulate each of subplots
ax = []

for i in range(columns * rows):
    img, label = test_set[i]
    pred_label = int(pred[i].cpu())
    # create subplot and append to ax
    ax.append(fig.add_subplot(rows, columns, i + 1))
    ax[-1].set_title(f"Label: {label}; Pred: {pred_label}" )  # set title
    plt.imshow(img)
plt.suptitle("ERM Prediction on Test Dataset", y = 0.92)
plt.savefig("ERM Prediction on Test Dataset.png")
plt.show()  # finally, render the plot
